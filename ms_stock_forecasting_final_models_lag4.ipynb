# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
# Load data (data source: https://finance.yahoo.com/quote/MSFT/history/)
data = pd.read_csv(r"C:\Users\htet\Documents\backup\prediction_ms_stock_prices\MSFT.csv")
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063907
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...          ...         ...         ...         ...         ...         ...
# 9356  2023-04-27  295.970001  305.200012  295.250000  304.829987  304.829987
# 9357  2023-04-28  304.010010  308.929993  303.309998  307.260010  307.260010
# 9358  2023-05-01  306.970001  308.600006  305.149994  305.559998  305.559998
# 9359  2023-05-02  307.760010  309.179993  303.910004  305.410004  305.410004
# 9360  2023-05-03  306.619995  308.609985  304.089996  304.399994  304.399994
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9356    46462600
# 9357    36446700
# 9358    21294100
# 9359    26404400
# 9360    22303300
#
# [9361 rows x 7 columns]

# %%
def drop_columns(dataframe, cols):
    dataframe = dataframe.drop(cols, axis=1)
    return dataframe

data = drop_columns(data, ["Open", "High", "Low", "Adj Close", "Volume"])
data.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
# Check null values
print("Null values in Date column: ", data.Close.isnull().sum())
print("Null values in Close column: ", data.Close.isnull().sum())
# Out:
# Null values in Date column:  0
# Null values in Close column:  0

# %%
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

data['Date'] = data['Date'].apply(str_to_datetime)
data['Date'].head()
# Out:
# 0   1986-03-13
# 1   1986-03-14
# 2   1986-03-17
# 3   1986-03-18
# 4   1986-03-19
# Name: Date, dtype: datetime64[ns]

# %%
data = data.set_index("Date")
data.head()
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090

# %%
data['Close'].describe()
# Out:
# count    9361.000000
# mean       47.864888
# std        69.759779
# min         0.090278
# 25%         5.304688
# 50%        27.080000
# 75%        43.360001
# max       343.109985
# Name: Close, dtype: float64

# %%
# Plot yearly closing values over time
plt.plot(data.index, data['Close'])
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Closing Values Over Time")
plt.grid()

# %%
# Yearly data distribution
data_year = data.Close.resample('Y').mean()
print(data_year.describe())

# Plot quaterly closing value over time
plt.plot(data_year.index, data_year)
plt.xlabel("Year")
plt.ylabel("Close")
plt.grid()
plt.title("Yearly Closing Value Over Time")
# Out:
# count     38.000000
# mean      51.474578
# std       75.109397
# min        0.117596
# 25%        5.778952
# 50%       26.852981
# 75%       43.438429
# max      275.940754
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Yearly Closing Value Over Time')

# %%
# Quarterly data distribution
data_quarter = data.Close.resample('Q').mean()
print(data_quarter.describe())

# Plot closing value over time
plt.plot(data_quarter.index, data_quarter)
plt.xlabel("Quarter")
plt.ylabel("Close")
plt.grid()
plt.title("Quarterly Closing Value Over Time")
# Out:
# count    150.000000
# mean      48.710331
# std       71.435336
# min        0.096282
# 25%        5.267330
# 50%       27.024108
# 75%       44.339050
# max      324.210157
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Quarterly Closing Value Over Time')

# %%
# Monthly data distribution
data_month = data.Close.resample('M').mean()
print(data_month.describe())

# Plot Monthly closing value over time
plt.plot(data_month.index, data_month)
plt.xlabel("Month")
plt.ylabel("Close")
plt.grid()
plt.title("Monthly Closing Value Over Time")
# Out:
# count    447.000000
# mean      48.411090
# std       70.663067
# min        0.096282
# 25%        5.456676
# 50%       27.075263
# 75%       43.514048
# max      335.870950
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Monthly Closing Value Over Time')

# %%
# Create windows based on lags
def create_window(df, lag):
    if lag < len(df):
        l = lag

        while True:
            df[f"Target_Close_{l}"] = df.Close.shift(l)

            l = l-1
            if l<1:
                break
        
        df["Target"] = df.Close.copy()
        return df
    
    else:
        raise ValueError(f"Lag value ({lag}) should be less than the size of data ({len(df)}).")

try:
    lag = 4
    target_data = data.copy()
    target_data = create_window(target_data, lag)
     
except ValueError as e:
    print(str(e))
    
target_data
# Out:
#                  Close  Target_Close_4  Target_Close_3  Target_Close_2  \
# Date
# 1986-03-13    0.097222             NaN             NaN             NaN
# 1986-03-14    0.100694             NaN             NaN             NaN
# 1986-03-17    0.102431             NaN             NaN        0.097222
# 1986-03-18    0.099826             NaN        0.097222        0.100694
# 1986-03-19    0.098090        0.097222        0.100694        0.102431
# ...                ...             ...             ...             ...
# 2023-04-27  304.829987      285.760010      281.769989      275.420013
# 2023-04-28  307.260010      281.769989      275.420013      295.369995
# 2023-05-01  305.559998      275.420013      295.369995      304.829987
# 2023-05-02  305.410004      295.369995      304.829987      307.260010
# 2023-05-03  304.399994      304.829987      307.260010      305.559998
#
#             Target_Close_1      Target
# Date
# 1986-03-13             NaN    0.097222
# 1986-03-14        0.097222    0.100694
# 1986-03-17        0.100694    0.102431
# 1986-03-18        0.102431    0.099826
# 1986-03-19        0.099826    0.098090
# ...                    ...         ...
# 2023-04-27      295.369995  304.829987
# 2023-04-28      304.829987  307.260010
# 2023-05-01      307.260010  305.559998
# 2023-05-02      305.559998  305.410004
# 2023-05-03      305.410004  304.399994
#
# [9361 rows x 6 columns]

# %%
# Delete redundant columns
deleted_cols = ["Close"]
target_data = drop_columns(target_data, deleted_cols)
target_data
# Out:
#             Target_Close_4  Target_Close_3  Target_Close_2  Target_Close_1  \
# Date
# 1986-03-13             NaN             NaN             NaN             NaN
# 1986-03-14             NaN             NaN             NaN        0.097222
# 1986-03-17             NaN             NaN        0.097222        0.100694
# 1986-03-18             NaN        0.097222        0.100694        0.102431
# 1986-03-19        0.097222        0.100694        0.102431        0.099826
# ...                    ...             ...             ...             ...
# 2023-04-27      285.760010      281.769989      275.420013      295.369995
# 2023-04-28      281.769989      275.420013      295.369995      304.829987
# 2023-05-01      275.420013      295.369995      304.829987      307.260010
# 2023-05-02      295.369995      304.829987      307.260010      305.559998
# 2023-05-03      304.829987      307.260010      305.559998      305.410004
#
#                 Target
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-04-27  304.829987
# 2023-04-28  307.260010
# 2023-05-01  305.559998
# 2023-05-02  305.410004
# 2023-05-03  304.399994
#
# [9361 rows x 5 columns]

# %%
# Choose data period
def selected_targets(dataframe, first_date, last_date):
    if first_date > dataframe.index[lag-1]:
        target_selected = dataframe.loc[first_date:last_date]
        return target_selected
    else:
        raise ValueError(f"First date should be greater than {first_date}.")     

try:  
    first_date = '1986-03-20'
    last_date = '2023-05-03'
    target_selected = selected_targets(target_data, str_to_datetime(first_date), str_to_datetime(last_date))
    print("Selected target shape: ", target_selected.shape)
    
except ValueError as e:
    print(str(e))
# Out:
# Selected target shape:  (9356, 5)

# %%
# Prepare data
def prepare_data(df):
    # convert df to numpy array
    dates = df.index.to_numpy()
    X = df.to_numpy()[:, :-1]
    y = df.to_numpy()[:, -1]
    return dates, X, y
    
dates, X, y = prepare_data(target_selected)
dates.shape, X.shape, y.shape
# Out:
# ((9356,), (9356, 4), (9356,))

# %%
# Split train and test data
train_size = int(len(dates)*0.8)
dates_train = dates[:train_size]
X_train = X[:train_size]
y_train = y[:train_size]
dates_test = dates[train_size:]
X_test = X[train_size:]
y_test = y[train_size:]

X_train.shape, X_test.shape
# Out:
# ((7484, 4), (1872, 4))

# %%
# Split train and validation data
train_nn_size = int(len(dates_train)*0.8)
dates_train_nn = dates_train[:train_nn_size]
X_train_nn = X_train[:train_nn_size]
y_train_nn = y_train[:train_nn_size]
dates_val_nn = dates_train[train_nn_size:]
X_val_nn = X_train[train_nn_size:]
y_val_nn = y_train[train_nn_size:]

X_train_nn.shape, X_val_nn.shape
# Out:
# ((5987, 4), (1497, 4))

# %%
# Standardize X data
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_train_nn = scaler.transform(X_train_nn)
X_val_nn = scaler.transform(X_val_nn)

# %%
# Plot train and test data
plt.plot(dates_train, y_train)
plt.plot(dates_test, y_test)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Closing Values Over Time of Train and Test Data")
plt.grid()
plt.legend(["Train", "Test"])

# %%
# Train and test target data distribution
pd.DataFrame(y_train).describe(), pd.DataFrame(y_test).describe()
# Out:
# (                 0
#  count  7484.000000
#  mean     19.820053
#  std      14.861314
#  min       0.090278
#  25%       2.667643
#  50%      25.085000
#  75%      29.350000
#  max      59.562500,
#                   0
#  count  1872.000000
#  mean    160.111880
#  std      87.769884
#  min      48.430000
#  25%      75.407501
#  50%     137.099998
#  75%     242.497501
#  max     343.109985)

# %%
# Create linear regression model
model_lr = LinearRegression(fit_intercept='True')
model_sv = SVR(kernel='linear', C=0.1, epsilon=0.1)
model_rf = RandomForestRegressor(n_estimators=50, max_depth=None)
model_gb = GradientBoostingRegressor(n_estimators=50, learning_rate=0.1, max_depth=3)
model_kn = KNeighborsRegressor(n_neighbors=3, weights='uniform')

# Set the time series cross-validation scheme
tscv = TimeSeriesSplit(n_splits=6)
mae_scores_lr = 0.0
mae_scores_sv = 0.0
mae_scores_rf = 0.0
mae_scores_gb = 0.0
mae_scores_kn = 0.0

for train_index, val_index in tscv.split(X_train):
    X_train_cv, X_val = X_train[train_index], X_train[val_index]
    y_train_cv, y_val = y_train[train_index], y_train[val_index]
    
    # Train models
    model_lr.fit(X_train, y_train)
    model_sv.fit(X_train, y_train)
    model_rf.fit(X_train, y_train)
    model_gb.fit(X_train, y_train)
    model_kn.fit(X_train, y_train)

    # Evaluate performance on the validation set
    y_pred_val_lr = model_lr.predict(X_val)
    y_pred_val_sv = model_sv.predict(X_val)
    y_pred_val_rf = model_rf.predict(X_val)
    y_pred_val_gb = model_gb.predict(X_val)
    y_pred_val_kn = model_kn.predict(X_val)
    mae_scores_lr += mean_absolute_error(y_val, y_pred_val_lr)
    mae_scores_sv += mean_absolute_error(y_val, y_pred_val_sv)
    mae_scores_rf += mean_absolute_error(y_val, y_pred_val_rf)
    mae_scores_gb += mean_absolute_error(y_val, y_pred_val_gb)
    mae_scores_kn += mean_absolute_error(y_val, y_pred_val_kn)

print("***Validation Scores***")
print('Validation MAE (Linear Regression): ', mae_scores_lr)
print('Validation MAE (Support Vector Regressor): ', mae_scores_sv)
print('Validation MAE (Random Forest Regressor): ', mae_scores_rf)
print('Validation MAE (Gradient Boosting Regressor): ', mae_scores_gb)
print('Validation MAE (KNeighbors regressor): ', mae_scores_kn)
# Out:
# ***Validation Scores***
# Validation MAE (Linear Regression):  1.945232227104111
# Validation MAE (Support Vector Regressor):  2.1167853605458253
# Validation MAE (Random Forest Regressor):  0.8140795993077649
# Validation MAE (Gradient Boosting Regressor):  1.9916038326670278
# Validation MAE (KNeighbors regressor):  1.6935508419083256

# %%
# Define the hyperparameters for neural networks
best_hps = {'num_layers': 35, 'units_0': 288, 'units_1': 960, 'learning_rate': 0.0001, 'units_2': 288, 'units_3': 128, 
            'units_4': 288, 'units_5': 256, 'units_6': 64, 'units_7': 192, 'units_8': 672, 'units_9': 416, 'units_10': 896, 
            'units_11': 352, 'units_12': 704, 'units_13': 736, 'units_14': 672, 'units_15': 384, 'units_16': 608, 
            'units_17': 224, 'units_18': 544, 'units_19': 256, 'units_20': 288, 'units_21': 320, 'units_22': 992, 
            'units_23': 544, 'units_24': 768, 'units_25': 576, 'units_26': 128, 'units_27': 96, 'units_28': 928, 
            'units_29': 544, 'units_30': 864, 'units_31': 544, 'units_32': 32, 'units_33': 864, 'units_34': 192, 
            'units_35': 352, 'units_36': 608, 'units_37': 320, 'units_38': 1024, 'units_39': 352, 'units_40': 192}

# Build the model
model_nn = Sequential()
for i in range(best_hps['num_layers']):
    units = best_hps[f'units_{i}']
    if i == 0:
        model_nn.add(Dense(units=units, activation='relu', input_shape=(lag,)))
    else:
        model_nn.add(Dense(units=units, activation='relu'))
model_nn.add(Dense(units=1, activation='linear'))

# Compile the model
optimizer = Adam(learning_rate=best_hps['learning_rate'])
model_nn.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mean_absolute_error'])

# Train the model using the full training set
history = model_nn.fit(X_train_nn, y_train_nn, epochs=100, validation_data=(X_val_nn, y_val_nn))
# Out:
# Epoch 1/100
# 188/188 [==============================] - 26s 111ms/step - loss: 5.7955 - mean_absolute_error: 5.7955 - val_loss: 0.9768 - val_mean_absolute_error: 0.9768
# Epoch 2/100
# 188/188 [==============================] - 18s 95ms/step - loss: 0.9879 - mean_absolute_error: 0.9879 - val_loss: 0.7333 - val_mean_absolute_error: 0.7333
# Epoch 3/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.9009 - mean_absolute_error: 0.9009 - val_loss: 2.1765 - val_mean_absolute_error: 2.1765
# Epoch 4/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.6975 - mean_absolute_error: 0.6975 - val_loss: 1.2363 - val_mean_absolute_error: 1.2363
# Epoch 5/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.6939 - mean_absolute_error: 0.6939 - val_loss: 0.6475 - val_mean_absolute_error: 0.6475
# Epoch 6/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.6083 - mean_absolute_error: 0.6083 - val_loss: 0.3837 - val_mean_absolute_error: 0.3837
# Epoch 7/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.5249 - mean_absolute_error: 0.5249 - val_loss: 0.6663 - val_mean_absolute_error: 0.6663
# Epoch 8/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.8150 - mean_absolute_error: 0.8150 - val_loss: 1.1416 - val_mean_absolute_error: 1.1416
# Epoch 9/100
# 188/188 [==============================] - 18s 93ms/step - loss: 0.7954 - mean_absolute_error: 0.7954 - val_loss: 0.7579 - val_mean_absolute_error: 0.7579
# Epoch 10/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.9825 - mean_absolute_error: 0.9825 - val_loss: 0.4262 - val_mean_absolute_error: 0.4262
# Epoch 11/100
# 188/188 [==============================] - 18s 93ms/step - loss: 0.5714 - mean_absolute_error: 0.5714 - val_loss: 0.3952 - val_mean_absolute_error: 0.3952
# Epoch 12/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.7736 - mean_absolute_error: 0.7736 - val_loss: 2.3558 - val_mean_absolute_error: 2.3558
# Epoch 13/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.7117 - mean_absolute_error: 0.7117 - val_loss: 0.7998 - val_mean_absolute_error: 0.7998
# Epoch 14/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.7159 - mean_absolute_error: 0.7159 - val_loss: 2.6192 - val_mean_absolute_error: 2.6192
# Epoch 15/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.5645 - mean_absolute_error: 0.5645 - val_loss: 3.4620 - val_mean_absolute_error: 3.4620
# Epoch 16/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.5938 - mean_absolute_error: 0.5938 - val_loss: 0.5853 - val_mean_absolute_error: 0.5853
# Epoch 17/100
# 188/188 [==============================] - 18s 93ms/step - loss: 0.6190 - mean_absolute_error: 0.6190 - val_loss: 2.2782 - val_mean_absolute_error: 2.2782
# Epoch 18/100
# 188/188 [==============================] - 18s 93ms/step - loss: 0.7527 - mean_absolute_error: 0.7527 - val_loss: 0.8156 - val_mean_absolute_error: 0.8156
# Epoch 19/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.5489 - mean_absolute_error: 0.5489 - val_loss: 0.6138 - val_mean_absolute_error: 0.6138
# Epoch 20/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.6413 - mean_absolute_error: 0.6413 - val_loss: 1.4189 - val_mean_absolute_error: 1.4189
# Epoch 21/100
# 188/188 [==============================] - 18s 93ms/step - loss: 0.5118 - mean_absolute_error: 0.5118 - val_loss: 2.5627 - val_mean_absolute_error: 2.5627
# Epoch 22/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.5590 - mean_absolute_error: 0.5590 - val_loss: 0.4109 - val_mean_absolute_error: 0.4109
# Epoch 23/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.6543 - mean_absolute_error: 0.6543 - val_loss: 2.7850 - val_mean_absolute_error: 2.7850
# Epoch 24/100
# 188/188 [==============================] - 18s 93ms/step - loss: 0.7888 - mean_absolute_error: 0.7888 - val_loss: 1.7276 - val_mean_absolute_error: 1.7276
# Epoch 25/100
# 188/188 [==============================] - 18s 93ms/step - loss: 0.5610 - mean_absolute_error: 0.5610 - val_loss: 1.4033 - val_mean_absolute_error: 1.4033
# Epoch 26/100
# 188/188 [==============================] - 18s 95ms/step - loss: 0.4987 - mean_absolute_error: 0.4987 - val_loss: 2.8340 - val_mean_absolute_error: 2.8340
# Epoch 27/100
# 188/188 [==============================] - 18s 95ms/step - loss: 0.6330 - mean_absolute_error: 0.6330 - val_loss: 1.6561 - val_mean_absolute_error: 1.6561
# Epoch 28/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.5990 - mean_absolute_error: 0.5990 - val_loss: 1.5590 - val_mean_absolute_error: 1.5590
# Epoch 29/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.5626 - mean_absolute_error: 0.5626 - val_loss: 0.4183 - val_mean_absolute_error: 0.4183
# Epoch 30/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.5113 - mean_absolute_error: 0.5113 - val_loss: 1.2811 - val_mean_absolute_error: 1.2811
# Epoch 31/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.4416 - mean_absolute_error: 0.4416 - val_loss: 1.2284 - val_mean_absolute_error: 1.2284
# Epoch 32/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.5528 - mean_absolute_error: 0.5528 - val_loss: 1.0224 - val_mean_absolute_error: 1.0224
# Epoch 33/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.5091 - mean_absolute_error: 0.5091 - val_loss: 1.0292 - val_mean_absolute_error: 1.0292
# Epoch 34/100
# 188/188 [==============================] - 17s 93ms/step - loss: 0.5854 - mean_absolute_error: 0.5854 - val_loss: 1.8619 - val_mean_absolute_error: 1.8619
# Epoch 35/100
# 188/188 [==============================] - 17s 92ms/step - loss: 0.5669 - mean_absolute_error: 0.5669 - val_loss: 0.7127 - val_mean_absolute_error: 0.7127
# Epoch 36/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.5812 - mean_absolute_error: 0.5812 - val_loss: 2.3081 - val_mean_absolute_error: 2.3081
# Epoch 37/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.6305 - mean_absolute_error: 0.6305 - val_loss: 0.3635 - val_mean_absolute_error: 0.3635
# Epoch 38/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.6481 - mean_absolute_error: 0.6481 - val_loss: 1.5685 - val_mean_absolute_error: 1.5685
# Epoch 39/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5319 - mean_absolute_error: 0.5319 - val_loss: 2.0568 - val_mean_absolute_error: 2.0568
# Epoch 40/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5454 - mean_absolute_error: 0.5454 - val_loss: 1.4706 - val_mean_absolute_error: 1.4706
# Epoch 41/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.5420 - mean_absolute_error: 0.5420 - val_loss: 2.6521 - val_mean_absolute_error: 2.6521
# Epoch 42/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5732 - mean_absolute_error: 0.5732 - val_loss: 2.0178 - val_mean_absolute_error: 2.0178
# Epoch 43/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5432 - mean_absolute_error: 0.5432 - val_loss: 1.8926 - val_mean_absolute_error: 1.8926
# Epoch 44/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4913 - mean_absolute_error: 0.4913 - val_loss: 0.6014 - val_mean_absolute_error: 0.6014
# Epoch 45/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5691 - mean_absolute_error: 0.5691 - val_loss: 0.6448 - val_mean_absolute_error: 0.6448
# Epoch 46/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.5516 - mean_absolute_error: 0.5516 - val_loss: 1.1323 - val_mean_absolute_error: 1.1323
# Epoch 47/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4969 - mean_absolute_error: 0.4969 - val_loss: 0.4036 - val_mean_absolute_error: 0.4036
# Epoch 48/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.8900 - mean_absolute_error: 0.8900 - val_loss: 2.7823 - val_mean_absolute_error: 2.7823
# Epoch 49/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5136 - mean_absolute_error: 0.5136 - val_loss: 2.5461 - val_mean_absolute_error: 2.5461
# Epoch 50/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4656 - mean_absolute_error: 0.4656 - val_loss: 1.0756 - val_mean_absolute_error: 1.0756
# Epoch 51/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4836 - mean_absolute_error: 0.4836 - val_loss: 0.3852 - val_mean_absolute_error: 0.3852
# Epoch 52/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4743 - mean_absolute_error: 0.4743 - val_loss: 1.9644 - val_mean_absolute_error: 1.9644
# Epoch 53/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5134 - mean_absolute_error: 0.5134 - val_loss: 3.3403 - val_mean_absolute_error: 3.3403
# Epoch 54/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5945 - mean_absolute_error: 0.5945 - val_loss: 1.1051 - val_mean_absolute_error: 1.1051
# Epoch 55/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4826 - mean_absolute_error: 0.4826 - val_loss: 0.7610 - val_mean_absolute_error: 0.7610
# Epoch 56/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4725 - mean_absolute_error: 0.4725 - val_loss: 0.3704 - val_mean_absolute_error: 0.3704
# Epoch 57/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5644 - mean_absolute_error: 0.5644 - val_loss: 1.3131 - val_mean_absolute_error: 1.3131
# Epoch 58/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4494 - mean_absolute_error: 0.4494 - val_loss: 1.0518 - val_mean_absolute_error: 1.0518
# Epoch 59/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5405 - mean_absolute_error: 0.5405 - val_loss: 2.0309 - val_mean_absolute_error: 2.0309
# Epoch 60/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4533 - mean_absolute_error: 0.4533 - val_loss: 0.3821 - val_mean_absolute_error: 0.3821
# Epoch 61/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.5415 - mean_absolute_error: 0.5415 - val_loss: 1.3238 - val_mean_absolute_error: 1.3238
# Epoch 62/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4461 - mean_absolute_error: 0.4461 - val_loss: 0.8360 - val_mean_absolute_error: 0.8360
# Epoch 63/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.6238 - mean_absolute_error: 0.6238 - val_loss: 1.1168 - val_mean_absolute_error: 1.1168
# Epoch 64/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4406 - mean_absolute_error: 0.4406 - val_loss: 2.1423 - val_mean_absolute_error: 2.1423
# Epoch 65/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5153 - mean_absolute_error: 0.5153 - val_loss: 1.5446 - val_mean_absolute_error: 1.5446
# Epoch 66/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.5769 - mean_absolute_error: 0.5769 - val_loss: 0.3734 - val_mean_absolute_error: 0.3734
# Epoch 67/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4810 - mean_absolute_error: 0.4810 - val_loss: 0.6835 - val_mean_absolute_error: 0.6835
# Epoch 68/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5164 - mean_absolute_error: 0.5164 - val_loss: 0.4283 - val_mean_absolute_error: 0.4283
# Epoch 69/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4482 - mean_absolute_error: 0.4482 - val_loss: 1.8698 - val_mean_absolute_error: 1.8698
# Epoch 70/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.6004 - mean_absolute_error: 0.6004 - val_loss: 1.4764 - val_mean_absolute_error: 1.4764
# Epoch 71/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5269 - mean_absolute_error: 0.5269 - val_loss: 0.6629 - val_mean_absolute_error: 0.6629
# Epoch 72/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.5117 - mean_absolute_error: 0.5117 - val_loss: 1.0212 - val_mean_absolute_error: 1.0212
# Epoch 73/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4941 - mean_absolute_error: 0.4941 - val_loss: 0.7703 - val_mean_absolute_error: 0.7703
# Epoch 74/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4834 - mean_absolute_error: 0.4834 - val_loss: 1.0749 - val_mean_absolute_error: 1.0749
# Epoch 75/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4694 - mean_absolute_error: 0.4694 - val_loss: 0.6736 - val_mean_absolute_error: 0.6736
# Epoch 76/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5088 - mean_absolute_error: 0.5088 - val_loss: 1.1260 - val_mean_absolute_error: 1.1260
# Epoch 77/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.5000 - mean_absolute_error: 0.5000 - val_loss: 0.6883 - val_mean_absolute_error: 0.6883
# Epoch 78/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.4549 - mean_absolute_error: 0.4549 - val_loss: 0.8169 - val_mean_absolute_error: 0.8169
# Epoch 79/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.5491 - mean_absolute_error: 0.5491 - val_loss: 0.6357 - val_mean_absolute_error: 0.6357
# Epoch 80/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4975 - mean_absolute_error: 0.4975 - val_loss: 2.3032 - val_mean_absolute_error: 2.3032
# Epoch 81/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4741 - mean_absolute_error: 0.4741 - val_loss: 0.3678 - val_mean_absolute_error: 0.3678
# Epoch 82/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4003 - mean_absolute_error: 0.4003 - val_loss: 2.3301 - val_mean_absolute_error: 2.3301
# Epoch 83/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4667 - mean_absolute_error: 0.4667 - val_loss: 2.3506 - val_mean_absolute_error: 2.3506
# Epoch 84/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.4712 - mean_absolute_error: 0.4712 - val_loss: 1.2289 - val_mean_absolute_error: 1.2289
# Epoch 85/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.3965 - mean_absolute_error: 0.3965 - val_loss: 0.5163 - val_mean_absolute_error: 0.5163
# Epoch 86/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4217 - mean_absolute_error: 0.4217 - val_loss: 1.3656 - val_mean_absolute_error: 1.3656
# Epoch 87/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.4962 - mean_absolute_error: 0.4962 - val_loss: 1.7503 - val_mean_absolute_error: 1.7503
# Epoch 88/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4610 - mean_absolute_error: 0.4610 - val_loss: 0.3527 - val_mean_absolute_error: 0.3527
# Epoch 89/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.4893 - mean_absolute_error: 0.4893 - val_loss: 0.6044 - val_mean_absolute_error: 0.6044
# Epoch 90/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4787 - mean_absolute_error: 0.4787 - val_loss: 1.4400 - val_mean_absolute_error: 1.4400
# Epoch 91/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4642 - mean_absolute_error: 0.4642 - val_loss: 0.9590 - val_mean_absolute_error: 0.9590
# Epoch 92/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4420 - mean_absolute_error: 0.4420 - val_loss: 0.3999 - val_mean_absolute_error: 0.3999
# Epoch 93/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.4523 - mean_absolute_error: 0.4523 - val_loss: 0.9549 - val_mean_absolute_error: 0.9549
# Epoch 94/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4109 - mean_absolute_error: 0.4109 - val_loss: 2.0081 - val_mean_absolute_error: 2.0081
# Epoch 95/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4543 - mean_absolute_error: 0.4543 - val_loss: 0.3562 - val_mean_absolute_error: 0.3562
# Epoch 96/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4856 - mean_absolute_error: 0.4856 - val_loss: 0.3790 - val_mean_absolute_error: 0.3790
# Epoch 97/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.4179 - mean_absolute_error: 0.4179 - val_loss: 0.9103 - val_mean_absolute_error: 0.9103
# Epoch 98/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.4311 - mean_absolute_error: 0.4311 - val_loss: 1.7251 - val_mean_absolute_error: 1.7251
# Epoch 99/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4766 - mean_absolute_error: 0.4766 - val_loss: 1.0719 - val_mean_absolute_error: 1.0719
# Epoch 100/100
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4286 - mean_absolute_error: 0.4286 - val_loss: 0.8879 - val_mean_absolute_error: 0.8879

# %%
# Save the models
path = r'C:\Users\htet\Documents\backup\prediction_ms_stock_prices'

with open(path + r"\model_lr_lag4.pkl", 'wb') as f:
    pickle.dump(model_lr, f)
    
with open(path + r"\model_sv_lag4.pkl", 'wb') as f:
    pickle.dump(model_sv, f)

with open(path + r"\model_rf_lag4.pkl", 'wb') as f:
    pickle.dump(model_rf, f)
    
with open(path + r"\model_gb_lag4.pkl", 'wb') as f:
    pickle.dump(model_gb, f)
    
with open(path + r"\model_kn_lag4.pkl", 'wb') as f:
    pickle.dump(model_kn, f)
    
with open(path + r"\model_nn_lag4.pkl", 'wb') as f:
    pickle.dump(model_nn, f)

# %%
# Make predictions
y_pred_test_lr = model_lr.predict(X_test)
y_pred_test_sv = model_sv.predict(X_test)
y_pred_test_rf = model_rf.predict(X_test)
y_pred_test_gb = model_gb.predict(X_test)
y_pred_test_kn = model_kn.predict(X_test)
y_pred_test_nn = model_nn.predict(X_test)

# Evaluate model performance
mae_lr = mean_absolute_error(y_test, y_pred_test_lr)
mae_sv = mean_absolute_error(y_test, y_pred_test_sv)
mae_rf = mean_absolute_error(y_test, y_pred_test_rf)
mae_gb = mean_absolute_error(y_test, y_pred_test_gb)
mae_kn = mean_absolute_error(y_test, y_pred_test_kn)
mae_nn = mean_absolute_error(y_test, y_pred_test_nn)

mse_lr = mean_squared_error(y_test, y_pred_test_lr)
mse_sv = mean_squared_error(y_test, y_pred_test_sv)
mse_rf = mean_squared_error(y_test, y_pred_test_rf)
mse_gb = mean_squared_error(y_test, y_pred_test_gb)
mse_kn = mean_squared_error(y_test, y_pred_test_kn)
mse_nn = mean_squared_error(y_test, y_pred_test_nn)

rmse_lr = mse_lr ** 0.5
rmse_sv = mse_sv ** 0.5
rmse_rf = mse_rf ** 0.5
rmse_gb = mse_gb ** 0.5
rmse_kn = mse_kn ** 0.5
rmse_nn = mse_nn ** 0.5

print("\n*****Testing score******")
print("\n***Linear Regression***")
print('MAE: %.2f' % mae_lr)
print('MSE: %.2f' % mse_lr)
print('RMSE: %.2f' % rmse_lr)
print("\n***Support Vector Regressor***")
print('MAE: %.2f' % mae_sv)
print('MSE: %.2f' % mse_sv)
print('RMSE: %.2f' % rmse_sv)
print("\n***Random Forest Regressor***")
print('MAE: %.2f' % mae_rf)
print('MSE: %.2f' % mse_rf)
print('RMSE: %.2f' % rmse_rf)
print("\n***Gradient Boosting Regressor***")
print('MAE: %.2f' % mae_gb)
print('MSE: %.2f' % mse_gb)
print('RMSE: %.2f' % rmse_gb)
print("\n***KNeighbors regressor***")
print('MAE: %.2f' % mae_kn)
print('MSE: %.2f' % mse_kn)
print('RMSE: %.2f' % rmse_kn)
print("\n***Neural Networks***")
print('MAE: %.2f' % mae_nn)
print('MSE: %.2f' % mse_nn)
print('RMSE: %.2f' % rmse_nn)
# Out:
# 59/59 [==============================] - 1s 14ms/step
#
# *****Testing score******
#
# ***Linear Regression***
# MAE: 2.10
# MSE: 11.63
# RMSE: 3.41
#
# ***Support Vector Regressor***
# MAE: 2.26
# MSE: 12.77
# RMSE: 3.57
#
# ***Random Forest Regressor***
# MAE: 102.61
# MSE: 18104.22
# RMSE: 134.55
#
# ***Gradient Boosting Regressor***
# MAE: 102.86
# MSE: 18159.83
# RMSE: 134.76
#
# ***KNeighbors regressor***
# MAE: 102.10
# MSE: 17976.67
# RMSE: 134.08
#
# ***Neural Networks***
# MAE: 6.51
# MSE: 67.21
# RMSE: 8.20

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_lr)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Linear Regression)")
plt.grid()
plt.legend(["Test observation", 
            "Linear Regression prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_sv)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Support Vector Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Support Vector Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_rf)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Random Forest Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Random Forest Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_gb)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Gradient Boosting Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Gradient Boosting Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_kn)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (KNeighbors Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "KNeighbors Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_nn)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Neural Networks)")
plt.grid()
plt.legend(["Test observation", 
            "Neural Networks prediction"])

# %%
# Predict new data
new_data = np.array(['2023-05-09', 304.40, 305.41, 310.65, 308.65, 307.00])
date_new = new_data[0]
X_new = new_data[1:-1]
X_new = X_new.reshape((-1, len(X_new)))
X_new = scaler.transform(X_new)
y_new = new_data[-1]

# Load the best model
with open(path + r"\model_lr_lag4.pkl", 'rb') as f:
    best_model_lr = pickle.load(f)
    
prediction = best_model_lr.predict(X_new)
print(f"Observation: {date_new} {float(y_new):.2f}")
print(f"Prediction: {date_new} {prediction[0]:.2f}")
# Out:
# Observation: 2023-05-09 307.00
# Prediction: 2023-05-09 308.61
