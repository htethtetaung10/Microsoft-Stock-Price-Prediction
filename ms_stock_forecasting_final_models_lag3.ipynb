# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
# Load data (data source: https://finance.yahoo.com/quote/MSFT/history/)
data = pd.read_csv(r"C:\Users\htet\Documents\backup\prediction_ms_stock_prices\MSFT.csv")
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063907
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...          ...         ...         ...         ...         ...         ...
# 9356  2023-04-27  295.970001  305.200012  295.250000  304.829987  304.829987
# 9357  2023-04-28  304.010010  308.929993  303.309998  307.260010  307.260010
# 9358  2023-05-01  306.970001  308.600006  305.149994  305.559998  305.559998
# 9359  2023-05-02  307.760010  309.179993  303.910004  305.410004  305.410004
# 9360  2023-05-03  306.619995  308.609985  304.089996  304.399994  304.399994
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9356    46462600
# 9357    36446700
# 9358    21294100
# 9359    26404400
# 9360    22303300
#
# [9361 rows x 7 columns]

# %%
def drop_columns(dataframe, cols):
    dataframe = dataframe.drop(cols, axis=1)
    return dataframe

data = drop_columns(data, ["Open", "High", "Low", "Adj Close", "Volume"])
data.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

data['Date'] = data['Date'].apply(str_to_datetime)
data['Date'].head()
# Out:
# 0   1986-03-13
# 1   1986-03-14
# 2   1986-03-17
# 3   1986-03-18
# 4   1986-03-19
# Name: Date, dtype: datetime64[ns]

# %%
data = data.set_index("Date")
data.head()
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090

# %%
data['Close'].describe()
# Out:
# count    9361.000000
# mean       47.864888
# std        69.759779
# min         0.090278
# 25%         5.304688
# 50%        27.080000
# 75%        43.360001
# max       343.109985
# Name: Close, dtype: float64

# %%
# Plot yearly closing values over time
plt.plot(data.index, data['Close'])
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Closing Values Over Time")
plt.grid()

# %%
# Yearly data distribution
data_year = data.Close.resample('Y').mean()
print(data_year.describe())

# Plot quaterly closing value over time
plt.plot(data_year.index, data_year)
plt.xlabel("Year")
plt.ylabel("Close")
plt.grid()
plt.title("Yearly Closing Value Over Time")
# Out:
# count     38.000000
# mean      51.474578
# std       75.109397
# min        0.117596
# 25%        5.778952
# 50%       26.852981
# 75%       43.438429
# max      275.940754
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Yearly Closing Value Over Time')

# %%
# Quarterly data distribution
data_quarter = data.Close.resample('Q').mean()
print(data_quarter.describe())

# Plot closing value over time
plt.plot(data_quarter.index, data_quarter)
plt.xlabel("Quarter")
plt.ylabel("Close")
plt.grid()
plt.title("Quarterly Closing Value Over Time")
# Out:
# count    150.000000
# mean      48.710331
# std       71.435336
# min        0.096282
# 25%        5.267330
# 50%       27.024108
# 75%       44.339050
# max      324.210157
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Quarterly Closing Value Over Time')

# %%
# Monthly data distribution
data_month = data.Close.resample('M').mean()
print(data_month.describe())

# Plot Monthly closing value over time
plt.plot(data_month.index, data_month)
plt.xlabel("Month")
plt.ylabel("Close")
plt.grid()
plt.title("Monthly Closing Value Over Time")
# Out:
# count    447.000000
# mean      48.411090
# std       70.663067
# min        0.096282
# 25%        5.456676
# 50%       27.075263
# 75%       43.514048
# max      335.870950
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Monthly Closing Value Over Time')

# %%
# Create windows based on lags
def create_window(df, lag):
    if lag < len(df):
        l = lag

        while True:
            df[f"Target_Close_{l}"] = df.Close.shift(l)

            l = l-1
            if l<1:
                break
        
        df["Target"] = df.Close.copy()
        return df
    
    else:
        raise ValueError(f"Lag value ({lag}) should be less than the size of data ({len(df)}).")

try:
    lag = 3
    target_data = data.copy()
    target_data = create_window(target_data, lag)
     
except ValueError as e:
    print(str(e))
    
target_data
# Out:
#                  Close  Target_Close_3  Target_Close_2  Target_Close_1  \
# Date
# 1986-03-13    0.097222             NaN             NaN             NaN
# 1986-03-14    0.100694             NaN             NaN        0.097222
# 1986-03-17    0.102431             NaN        0.097222        0.100694
# 1986-03-18    0.099826        0.097222        0.100694        0.102431
# 1986-03-19    0.098090        0.100694        0.102431        0.099826
# ...                ...             ...             ...             ...
# 2023-04-27  304.829987      281.769989      275.420013      295.369995
# 2023-04-28  307.260010      275.420013      295.369995      304.829987
# 2023-05-01  305.559998      295.369995      304.829987      307.260010
# 2023-05-02  305.410004      304.829987      307.260010      305.559998
# 2023-05-03  304.399994      307.260010      305.559998      305.410004
#
#                 Target
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-04-27  304.829987
# 2023-04-28  307.260010
# 2023-05-01  305.559998
# 2023-05-02  305.410004
# 2023-05-03  304.399994
#
# [9361 rows x 5 columns]

# %%
# Delete redundant columns
deleted_cols = ["Close"]
target_data = drop_columns(target_data, deleted_cols)
target_data
# Out:
#             Target_Close_3  Target_Close_2  Target_Close_1      Target
# Date
# 1986-03-13             NaN             NaN             NaN    0.097222
# 1986-03-14             NaN             NaN        0.097222    0.100694
# 1986-03-17             NaN        0.097222        0.100694    0.102431
# 1986-03-18        0.097222        0.100694        0.102431    0.099826
# 1986-03-19        0.100694        0.102431        0.099826    0.098090
# ...                    ...             ...             ...         ...
# 2023-04-27      281.769989      275.420013      295.369995  304.829987
# 2023-04-28      275.420013      295.369995      304.829987  307.260010
# 2023-05-01      295.369995      304.829987      307.260010  305.559998
# 2023-05-02      304.829987      307.260010      305.559998  305.410004
# 2023-05-03      307.260010      305.559998      305.410004  304.399994
#
# [9361 rows x 4 columns]

# %%
# Choose data period
def selected_targets(dataframe, first_date, last_date):
    if first_date > dataframe.index[lag-1]:
        target_selected = dataframe.loc[first_date:last_date]
        return target_selected
    else:
        raise ValueError(f"First date should be greater than {first_date}.")     

try:  
    first_date = '1986-03-20'
    last_date = '2023-05-03'
    target_selected = selected_targets(target_data, str_to_datetime(first_date), str_to_datetime(last_date))
    print("Selected target shape: ", target_selected.shape)
    
except ValueError as e:
    print(str(e))
# Out:
# Selected target shape:  (9356, 4)

# %%
# Prepare data
def prepare_data(df):
    # convert df to numpy array
    dates = df.index.to_numpy()
    X = df.to_numpy()[:, :-1]
    y = df.to_numpy()[:, -1]
    return dates, X, y
    
dates, X, y = prepare_data(target_selected)
dates.shape, X.shape, y.shape
# Out:
# ((9356,), (9356, 3), (9356,))

# %%
# Split train and test data
train_size = int(len(dates)*0.8)
dates_train = dates[:train_size]
X_train = X[:train_size]
y_train = y[:train_size]
dates_test = dates[train_size:]
X_test = X[train_size:]
y_test = y[train_size:]

X_train.shape, X_test.shape
# Out:
# ((7484, 3), (1872, 3))

# %%
# Split train and validation data
train_nn_size = int(len(dates_train)*0.8)
dates_train_nn = dates_train[:train_nn_size]
X_train_nn = X_train[:train_nn_size]
y_train_nn = y_train[:train_nn_size]
dates_val_nn = dates_train[train_nn_size:]
X_val_nn = X_train[train_nn_size:]
y_val_nn = y_train[train_nn_size:]

X_train_nn.shape, X_val_nn.shape
# Out:
# ((5987, 3), (1497, 3))

# %%
# Standardize X data
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_train_nn = scaler.transform(X_train_nn)
X_val_nn = scaler.transform(X_val_nn)

# %%
# Plot train and test data
plt.plot(dates_train, y_train)
plt.plot(dates_test, y_test)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Closing Values Over Time of Train and Test Data")
plt.grid()
plt.legend(["Train", "Test"])

# %%
# Train and test target data distribution
pd.DataFrame(y_train).describe(), pd.DataFrame(y_test).describe()
# Out:
# (                 0
#  count  7484.000000
#  mean     19.820053
#  std      14.861314
#  min       0.090278
#  25%       2.667643
#  50%      25.085000
#  75%      29.350000
#  max      59.562500,
#                   0
#  count  1872.000000
#  mean    160.111880
#  std      87.769884
#  min      48.430000
#  25%      75.407501
#  50%     137.099998
#  75%     242.497501
#  max     343.109985)

# %%
# Create linear regression model
model_lr = LinearRegression(fit_intercept='True')
model_sv = SVR(kernel='linear', C=0.1, epsilon=0.1)
model_rf = RandomForestRegressor(n_estimators=50, max_depth=None)
model_gb = GradientBoostingRegressor(n_estimators=50, learning_rate=0.1, max_depth=3)
model_kn = KNeighborsRegressor(n_neighbors=3, weights='uniform')

# Set the time series cross-validation scheme
tscv = TimeSeriesSplit(n_splits=6)
mae_scores_lr = 0.0
mae_scores_sv = 0.0
mae_scores_rf = 0.0
mae_scores_gb = 0.0
mae_scores_kn = 0.0

for train_index, val_index in tscv.split(X_train):
    X_train_cv, X_val = X_train[train_index], X_train[val_index]
    y_train_cv, y_val = y_train[train_index], y_train[val_index]
    
    # Train models
    model_lr.fit(X_train, y_train)
    model_sv.fit(X_train, y_train)
    model_rf.fit(X_train, y_train)
    model_gb.fit(X_train, y_train)
    model_kn.fit(X_train, y_train)

    # Evaluate performance on the validation set
    y_pred_val_lr = model_lr.predict(X_val)
    y_pred_val_sv = model_sv.predict(X_val)
    y_pred_val_rf = model_rf.predict(X_val)
    y_pred_val_gb = model_gb.predict(X_val)
    y_pred_val_kn = model_kn.predict(X_val)
    mae_scores_lr += mean_absolute_error(y_val, y_pred_val_lr)
    mae_scores_sv += mean_absolute_error(y_val, y_pred_val_sv)
    mae_scores_rf += mean_absolute_error(y_val, y_pred_val_rf)
    mae_scores_gb += mean_absolute_error(y_val, y_pred_val_gb)
    mae_scores_kn += mean_absolute_error(y_val, y_pred_val_kn)

print("***Validation Scores***")
print('Validation MAE (Linear Regression): ', mae_scores_lr)
print('Validation MAE (Support Vector Regressor): ', mae_scores_sv)
print('Validation MAE (Random Forest Regressor): ', mae_scores_rf)
print('Validation MAE (Gradient Boosting Regressor): ', mae_scores_gb)
print('Validation MAE (KNeighbors regressor): ', mae_scores_kn)
# Out:
# ***Validation Scores***
# Validation MAE (Linear Regression):  1.943789937471448
# Validation MAE (Support Vector Regressor):  2.0996814086656195
# Validation MAE (Random Forest Regressor):  0.8215988696351726
# Validation MAE (Gradient Boosting Regressor):  1.9931721107820188
# Validation MAE (KNeighbors regressor):  1.668810034299969

# %%
# Define the hyperparameters for neural networks
best_hps = {'num_layers': 24, 'units_0': 864, 'units_1': 288, 'learning_rate': 0.001, 'units_2': 480, 'units_3': 800, 
            'units_4': 576, 'units_5': 384, 'units_6': 64, 'units_7': 512, 'units_8': 352, 'units_9': 672, 'units_10': 64, 
            'units_11': 224, 'units_12': 448, 'units_13': 352, 'units_14': 768, 'units_15': 640, 'units_16': 832, 
            'units_17': 992, 'units_18': 224, 'units_19': 800, 'units_20': 64, 'units_21': 896, 'units_22': 512, 
            'units_23': 1024, 'units_24': 224, 'units_25': 160, 'units_26': 800}

# Build the model
model_nn = Sequential()
for i in range(best_hps['num_layers']):
    units = best_hps[f'units_{i}']
    if i == 0:
        model_nn.add(Dense(units=units, activation='relu', input_shape=(lag,)))
    else:
        model_nn.add(Dense(units=units, activation='relu'))
model_nn.add(Dense(units=1, activation='linear'))

# Compile the model
optimizer = Adam(learning_rate=best_hps['learning_rate'])
model_nn.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mean_absolute_error'])

# Train the model using the full training set
history = model_nn.fit(X_train_nn, y_train_nn, epochs=100, validation_data=(X_val_nn, y_val_nn))
# Out:
# Epoch 1/100
# 188/188 [==============================] - 19s 82ms/step - loss: 6.7628 - mean_absolute_error: 6.7628 - val_loss: 4.8736 - val_mean_absolute_error: 4.8736
# Epoch 2/100
# 188/188 [==============================] - 15s 82ms/step - loss: 2.3041 - mean_absolute_error: 2.3041 - val_loss: 0.9347 - val_mean_absolute_error: 0.9347
# Epoch 3/100
# 188/188 [==============================] - 15s 81ms/step - loss: 1.6874 - mean_absolute_error: 1.6874 - val_loss: 1.6764 - val_mean_absolute_error: 1.6764
# Epoch 4/100
# 188/188 [==============================] - 15s 81ms/step - loss: 1.0745 - mean_absolute_error: 1.0745 - val_loss: 1.3860 - val_mean_absolute_error: 1.3860
# Epoch 5/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.8659 - mean_absolute_error: 0.8659 - val_loss: 10.1481 - val_mean_absolute_error: 10.1481
# Epoch 6/100
# 188/188 [==============================] - 15s 82ms/step - loss: 1.2890 - mean_absolute_error: 1.2890 - val_loss: 1.7607 - val_mean_absolute_error: 1.7607
# Epoch 7/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.7099 - mean_absolute_error: 0.7099 - val_loss: 2.1147 - val_mean_absolute_error: 2.1147
# Epoch 8/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.8917 - mean_absolute_error: 0.8917 - val_loss: 1.8805 - val_mean_absolute_error: 1.8805
# Epoch 9/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6118 - mean_absolute_error: 0.6118 - val_loss: 2.1891 - val_mean_absolute_error: 2.1891
# Epoch 10/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6862 - mean_absolute_error: 0.6862 - val_loss: 0.5964 - val_mean_absolute_error: 0.5964
# Epoch 11/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6789 - mean_absolute_error: 0.6789 - val_loss: 0.5634 - val_mean_absolute_error: 0.5634
# Epoch 12/100
# 188/188 [==============================] - 15s 81ms/step - loss: 0.8448 - mean_absolute_error: 0.8448 - val_loss: 0.4488 - val_mean_absolute_error: 0.4488
# Epoch 13/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.8402 - mean_absolute_error: 0.8402 - val_loss: 0.7120 - val_mean_absolute_error: 0.7120
# Epoch 14/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6805 - mean_absolute_error: 0.6805 - val_loss: 2.2616 - val_mean_absolute_error: 2.2616
# Epoch 15/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.6152 - mean_absolute_error: 0.6152 - val_loss: 0.7259 - val_mean_absolute_error: 0.7259
# Epoch 16/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.6065 - mean_absolute_error: 0.6065 - val_loss: 2.8978 - val_mean_absolute_error: 2.8978
# Epoch 17/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.6136 - mean_absolute_error: 0.6136 - val_loss: 1.3054 - val_mean_absolute_error: 1.3054
# Epoch 18/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6967 - mean_absolute_error: 0.6967 - val_loss: 0.7467 - val_mean_absolute_error: 0.7467
# Epoch 19/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6315 - mean_absolute_error: 0.6315 - val_loss: 1.0631 - val_mean_absolute_error: 1.0631
# Epoch 20/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5654 - mean_absolute_error: 0.5654 - val_loss: 0.7155 - val_mean_absolute_error: 0.7155
# Epoch 21/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5814 - mean_absolute_error: 0.5814 - val_loss: 2.2382 - val_mean_absolute_error: 2.2382
# Epoch 22/100
# 188/188 [==============================] - 15s 80ms/step - loss: 0.5446 - mean_absolute_error: 0.5446 - val_loss: 0.3835 - val_mean_absolute_error: 0.3835
# Epoch 23/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5419 - mean_absolute_error: 0.5419 - val_loss: 0.6533 - val_mean_absolute_error: 0.6533
# Epoch 24/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5819 - mean_absolute_error: 0.5819 - val_loss: 0.6861 - val_mean_absolute_error: 0.6861
# Epoch 25/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5689 - mean_absolute_error: 0.5689 - val_loss: 1.8584 - val_mean_absolute_error: 1.8584
# Epoch 26/100
# 188/188 [==============================] - 16s 82ms/step - loss: 0.6627 - mean_absolute_error: 0.6627 - val_loss: 1.1035 - val_mean_absolute_error: 1.1035
# Epoch 27/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5710 - mean_absolute_error: 0.5710 - val_loss: 1.3468 - val_mean_absolute_error: 1.3468
# Epoch 28/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6153 - mean_absolute_error: 0.6153 - val_loss: 1.4771 - val_mean_absolute_error: 1.4771
# Epoch 29/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5809 - mean_absolute_error: 0.5809 - val_loss: 2.1095 - val_mean_absolute_error: 2.1095
# Epoch 30/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5421 - mean_absolute_error: 0.5421 - val_loss: 0.8157 - val_mean_absolute_error: 0.8157
# Epoch 31/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4700 - mean_absolute_error: 0.4700 - val_loss: 0.8821 - val_mean_absolute_error: 0.8821
# Epoch 32/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5262 - mean_absolute_error: 0.5262 - val_loss: 1.3855 - val_mean_absolute_error: 1.3855
# Epoch 33/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.7576 - mean_absolute_error: 0.7576 - val_loss: 0.6848 - val_mean_absolute_error: 0.6848
# Epoch 34/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5296 - mean_absolute_error: 0.5296 - val_loss: 0.6079 - val_mean_absolute_error: 0.6079
# Epoch 35/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5944 - mean_absolute_error: 0.5944 - val_loss: 0.8396 - val_mean_absolute_error: 0.8396
# Epoch 36/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.4502 - mean_absolute_error: 0.4502 - val_loss: 1.3323 - val_mean_absolute_error: 1.3323
# Epoch 37/100
# 188/188 [==============================] - 16s 82ms/step - loss: 0.5572 - mean_absolute_error: 0.5572 - val_loss: 3.4135 - val_mean_absolute_error: 3.4135
# Epoch 38/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5711 - mean_absolute_error: 0.5711 - val_loss: 2.0026 - val_mean_absolute_error: 2.0026
# Epoch 39/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4901 - mean_absolute_error: 0.4901 - val_loss: 1.2631 - val_mean_absolute_error: 1.2631
# Epoch 40/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5151 - mean_absolute_error: 0.5151 - val_loss: 0.8582 - val_mean_absolute_error: 0.8582
# Epoch 41/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5114 - mean_absolute_error: 0.5114 - val_loss: 1.4099 - val_mean_absolute_error: 1.4099
# Epoch 42/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5907 - mean_absolute_error: 0.5907 - val_loss: 2.7846 - val_mean_absolute_error: 2.7846
# Epoch 43/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5236 - mean_absolute_error: 0.5236 - val_loss: 1.7964 - val_mean_absolute_error: 1.7964
# Epoch 44/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.5428 - mean_absolute_error: 0.5428 - val_loss: 0.7340 - val_mean_absolute_error: 0.7340
# Epoch 45/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.5000 - mean_absolute_error: 0.5000 - val_loss: 1.9483 - val_mean_absolute_error: 1.9483
# Epoch 46/100
# 188/188 [==============================] - 16s 86ms/step - loss: 0.4311 - mean_absolute_error: 0.4311 - val_loss: 0.3940 - val_mean_absolute_error: 0.3940
# Epoch 47/100
# 188/188 [==============================] - 16s 88ms/step - loss: 0.4975 - mean_absolute_error: 0.4975 - val_loss: 1.4508 - val_mean_absolute_error: 1.4508
# Epoch 48/100
# 188/188 [==============================] - 17s 89ms/step - loss: 0.5164 - mean_absolute_error: 0.5164 - val_loss: 3.5909 - val_mean_absolute_error: 3.5909
# Epoch 49/100
# 188/188 [==============================] - 16s 86ms/step - loss: 0.5209 - mean_absolute_error: 0.5209 - val_loss: 0.5031 - val_mean_absolute_error: 0.5031
# Epoch 50/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.4725 - mean_absolute_error: 0.4725 - val_loss: 0.9774 - val_mean_absolute_error: 0.9774
# Epoch 51/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.5274 - mean_absolute_error: 0.5274 - val_loss: 0.6799 - val_mean_absolute_error: 0.6799
# Epoch 52/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.5390 - mean_absolute_error: 0.5390 - val_loss: 1.0396 - val_mean_absolute_error: 1.0396
# Epoch 53/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4715 - mean_absolute_error: 0.4715 - val_loss: 1.8558 - val_mean_absolute_error: 1.8558
# Epoch 54/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4949 - mean_absolute_error: 0.4949 - val_loss: 0.7341 - val_mean_absolute_error: 0.7341
# Epoch 55/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4384 - mean_absolute_error: 0.4384 - val_loss: 0.5843 - val_mean_absolute_error: 0.5843
# Epoch 56/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4538 - mean_absolute_error: 0.4538 - val_loss: 2.7860 - val_mean_absolute_error: 2.7860
# Epoch 57/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.5879 - mean_absolute_error: 0.5879 - val_loss: 0.4973 - val_mean_absolute_error: 0.4973
# Epoch 58/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4651 - mean_absolute_error: 0.4651 - val_loss: 1.5448 - val_mean_absolute_error: 1.5448
# Epoch 59/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4691 - mean_absolute_error: 0.4691 - val_loss: 1.1497 - val_mean_absolute_error: 1.1497
# Epoch 60/100
# 188/188 [==============================] - 16s 84ms/step - loss: 0.5157 - mean_absolute_error: 0.5157 - val_loss: 0.6936 - val_mean_absolute_error: 0.6936
# Epoch 61/100
# 188/188 [==============================] - 16s 84ms/step - loss: 0.4607 - mean_absolute_error: 0.4607 - val_loss: 0.4832 - val_mean_absolute_error: 0.4832
# Epoch 62/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4600 - mean_absolute_error: 0.4600 - val_loss: 0.4366 - val_mean_absolute_error: 0.4366
# Epoch 63/100
# 188/188 [==============================] - 16s 86ms/step - loss: 0.5213 - mean_absolute_error: 0.5213 - val_loss: 0.7012 - val_mean_absolute_error: 0.7012
# Epoch 64/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4563 - mean_absolute_error: 0.4563 - val_loss: 0.4384 - val_mean_absolute_error: 0.4384
# Epoch 65/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4799 - mean_absolute_error: 0.4799 - val_loss: 0.4282 - val_mean_absolute_error: 0.4282
# Epoch 66/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.5112 - mean_absolute_error: 0.5112 - val_loss: 1.2811 - val_mean_absolute_error: 1.2811
# Epoch 67/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4712 - mean_absolute_error: 0.4712 - val_loss: 0.4830 - val_mean_absolute_error: 0.4830
# Epoch 68/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4479 - mean_absolute_error: 0.4479 - val_loss: 0.4333 - val_mean_absolute_error: 0.4333
# Epoch 69/100
# 188/188 [==============================] - 16s 87ms/step - loss: 0.4297 - mean_absolute_error: 0.4297 - val_loss: 1.4920 - val_mean_absolute_error: 1.4920
# Epoch 70/100
# 188/188 [==============================] - 15s 80ms/step - loss: 0.4977 - mean_absolute_error: 0.4977 - val_loss: 0.8604 - val_mean_absolute_error: 0.8604
# Epoch 71/100
# 188/188 [==============================] - 16s 84ms/step - loss: 0.4631 - mean_absolute_error: 0.4631 - val_loss: 0.6787 - val_mean_absolute_error: 0.6787
# Epoch 72/100
# 188/188 [==============================] - 15s 81ms/step - loss: 0.4387 - mean_absolute_error: 0.4387 - val_loss: 0.3959 - val_mean_absolute_error: 0.3959
# Epoch 73/100
# 188/188 [==============================] - 16s 85ms/step - loss: 0.4456 - mean_absolute_error: 0.4456 - val_loss: 2.2312 - val_mean_absolute_error: 2.2312
# Epoch 74/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4802 - mean_absolute_error: 0.4802 - val_loss: 0.6777 - val_mean_absolute_error: 0.6777
# Epoch 75/100
# 188/188 [==============================] - 15s 81ms/step - loss: 0.4443 - mean_absolute_error: 0.4443 - val_loss: 0.9331 - val_mean_absolute_error: 0.9331
# Epoch 76/100
# 188/188 [==============================] - 15s 81ms/step - loss: 0.4817 - mean_absolute_error: 0.4817 - val_loss: 1.4514 - val_mean_absolute_error: 1.4514
# Epoch 77/100
# 188/188 [==============================] - 15s 81ms/step - loss: 0.4313 - mean_absolute_error: 0.4313 - val_loss: 0.9236 - val_mean_absolute_error: 0.9236
# Epoch 78/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4213 - mean_absolute_error: 0.4213 - val_loss: 0.7673 - val_mean_absolute_error: 0.7673
# Epoch 79/100
# 188/188 [==============================] - 15s 78ms/step - loss: 0.4568 - mean_absolute_error: 0.4568 - val_loss: 1.1420 - val_mean_absolute_error: 1.1420
# Epoch 80/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4394 - mean_absolute_error: 0.4394 - val_loss: 0.6073 - val_mean_absolute_error: 0.6073
# Epoch 81/100
# 188/188 [==============================] - 15s 79ms/step - loss: 0.4806 - mean_absolute_error: 0.4806 - val_loss: 0.7270 - val_mean_absolute_error: 0.7270
# Epoch 82/100
# 188/188 [==============================] - 17s 91ms/step - loss: 0.4488 - mean_absolute_error: 0.4488 - val_loss: 0.6561 - val_mean_absolute_error: 0.6561
# Epoch 83/100
# 188/188 [==============================] - 16s 87ms/step - loss: 0.4554 - mean_absolute_error: 0.4554 - val_loss: 0.7602 - val_mean_absolute_error: 0.7602
# Epoch 84/100
# 188/188 [==============================] - 16s 83ms/step - loss: 0.4114 - mean_absolute_error: 0.4114 - val_loss: 0.6714 - val_mean_absolute_error: 0.6714
# Epoch 85/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4355 - mean_absolute_error: 0.4355 - val_loss: 1.8430 - val_mean_absolute_error: 1.8430
# Epoch 86/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4222 - mean_absolute_error: 0.4222 - val_loss: 0.7309 - val_mean_absolute_error: 0.7309
# Epoch 87/100
# 188/188 [==============================] - 15s 80ms/step - loss: 0.4388 - mean_absolute_error: 0.4388 - val_loss: 0.5929 - val_mean_absolute_error: 0.5929
# Epoch 88/100
# 188/188 [==============================] - 15s 81ms/step - loss: 0.4565 - mean_absolute_error: 0.4565 - val_loss: 1.7186 - val_mean_absolute_error: 1.7186
# Epoch 89/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4227 - mean_absolute_error: 0.4227 - val_loss: 0.5199 - val_mean_absolute_error: 0.5199
# Epoch 90/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4390 - mean_absolute_error: 0.4390 - val_loss: 0.8632 - val_mean_absolute_error: 0.8632
# Epoch 91/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4364 - mean_absolute_error: 0.4364 - val_loss: 1.0250 - val_mean_absolute_error: 1.0250
# Epoch 92/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4310 - mean_absolute_error: 0.4310 - val_loss: 0.5134 - val_mean_absolute_error: 0.5134
# Epoch 93/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4247 - mean_absolute_error: 0.4247 - val_loss: 1.3395 - val_mean_absolute_error: 1.3395
# Epoch 94/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4123 - mean_absolute_error: 0.4123 - val_loss: 0.7579 - val_mean_absolute_error: 0.7579
# Epoch 95/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.3920 - mean_absolute_error: 0.3920 - val_loss: 1.0278 - val_mean_absolute_error: 1.0278
# Epoch 96/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4428 - mean_absolute_error: 0.4428 - val_loss: 0.7583 - val_mean_absolute_error: 0.7583
# Epoch 97/100
# 188/188 [==============================] - 15s 81ms/step - loss: 0.4040 - mean_absolute_error: 0.4040 - val_loss: 0.6357 - val_mean_absolute_error: 0.6357
# Epoch 98/100
# 188/188 [==============================] - 16s 87ms/step - loss: 0.4421 - mean_absolute_error: 0.4421 - val_loss: 0.6815 - val_mean_absolute_error: 0.6815
# Epoch 99/100
# 188/188 [==============================] - 15s 82ms/step - loss: 0.4295 - mean_absolute_error: 0.4295 - val_loss: 0.5779 - val_mean_absolute_error: 0.5779
# Epoch 100/100
# 188/188 [==============================] - 17s 88ms/step - loss: 0.4459 - mean_absolute_error: 0.4459 - val_loss: 0.7285 - val_mean_absolute_error: 0.7285

# %%
# Save the models
path = r'C:\Users\htet\Documents\backup\prediction_ms_stock_prices'

with open(path + r"\model_lr_lag3.pkl", 'wb') as f:
    pickle.dump(model_lr, f)
    
with open(path + r"\model_sv_lag3.pkl", 'wb') as f:
    pickle.dump(model_sv, f)

with open(path + r"\model_rf_lag3.pkl", 'wb') as f:
    pickle.dump(model_rf, f)
    
with open(path + r"\model_gb_lag3.pkl", 'wb') as f:
    pickle.dump(model_gb, f)
    
with open(path + r"\model_kn_lag3.pkl", 'wb') as f:
    pickle.dump(model_kn, f)
    
with open(path + r"\model_nn_lag3.pkl", 'wb') as f:
    pickle.dump(model_nn, f)

# %%
# Make predictions
y_pred_test_lr = model_lr.predict(X_test)
y_pred_test_sv = model_sv.predict(X_test)
y_pred_test_rf = model_rf.predict(X_test)
y_pred_test_gb = model_gb.predict(X_test)
y_pred_test_kn = model_kn.predict(X_test)
y_pred_test_nn = model_nn.predict(X_test)

# Evaluate model performance
mae_lr = mean_absolute_error(y_test, y_pred_test_lr)
mae_sv = mean_absolute_error(y_test, y_pred_test_sv)
mae_rf = mean_absolute_error(y_test, y_pred_test_rf)
mae_gb = mean_absolute_error(y_test, y_pred_test_gb)
mae_kn = mean_absolute_error(y_test, y_pred_test_kn)
mae_nn = mean_absolute_error(y_test, y_pred_test_nn)

mse_lr = mean_squared_error(y_test, y_pred_test_lr)
mse_sv = mean_squared_error(y_test, y_pred_test_sv)
mse_rf = mean_squared_error(y_test, y_pred_test_rf)
mse_gb = mean_squared_error(y_test, y_pred_test_gb)
mse_kn = mean_squared_error(y_test, y_pred_test_kn)
mse_nn = mean_squared_error(y_test, y_pred_test_nn)

rmse_lr = mse_lr ** 0.5
rmse_sv = mse_sv ** 0.5
rmse_rf = mse_rf ** 0.5
rmse_gb = mse_gb ** 0.5
rmse_kn = mse_kn ** 0.5
rmse_nn = mse_nn ** 0.5

print("\n*****Testing score******")
print("\n***Linear Regression***")
print('MAE: %.2f' % mae_lr)
print('MSE: %.2f' % mse_lr)
print('RMSE: %.2f' % rmse_lr)
print("\n***Support Vector Regressor***")
print('MAE: %.2f' % mae_sv)
print('MSE: %.2f' % mse_sv)
print('RMSE: %.2f' % rmse_sv)
print("\n***Random Forest Regressor***")
print('MAE: %.2f' % mae_rf)
print('MSE: %.2f' % mse_rf)
print('RMSE: %.2f' % rmse_rf)
print("\n***Gradient Boosting Regressor***")
print('MAE: %.2f' % mae_gb)
print('MSE: %.2f' % mse_gb)
print('RMSE: %.2f' % rmse_gb)
print("\n***KNeighbors regressor***")
print('MAE: %.2f' % mae_kn)
print('MSE: %.2f' % mse_kn)
print('RMSE: %.2f' % rmse_kn)
print("\n***Neural Networks***")
print('MAE: %.2f' % mae_nn)
print('MSE: %.2f' % mse_nn)
print('RMSE: %.2f' % rmse_nn)
# Out:
# 59/59 [==============================] - 1s 13ms/step
#
# *****Testing score******
#
# ***Linear Regression***
# MAE: 2.10
# MSE: 11.64
# RMSE: 3.41
#
# ***Support Vector Regressor***
# MAE: 2.25
# MSE: 12.68
# RMSE: 3.56
#
# ***Random Forest Regressor***
# MAE: 102.10
# MSE: 17985.23
# RMSE: 134.11
#
# ***Gradient Boosting Regressor***
# MAE: 102.86
# MSE: 18159.30
# RMSE: 134.76
#
# ***KNeighbors regressor***
# MAE: 101.97
# MSE: 17951.13
# RMSE: 133.98
#
# ***Neural Networks***
# MAE: 19.39
# MSE: 672.40
# RMSE: 25.93

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_lr)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Linear Regression)")
plt.grid()
plt.legend(["Test observation", 
            "Linear Regression prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_sv)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Support Vector Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Support Vector Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_rf)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Random Forest Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Random Forest Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_gb)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Gradient Boosting Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Gradient Boosting Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_kn)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (KNeighbors Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "KNeighbors Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_nn)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Neural Networks)")
plt.grid()
plt.legend(["Test observation", 
            "Neural Networks prediction"])

# %%
# Predict new data
new_data = np.array(['2023-05-09', 305.41, 310.65, 308.65, 307.00])
date_new = new_data[0]
X_new = new_data[1:-1]
X_new = X_new.reshape((-1, len(X_new)))
X_new = scaler.transform(X_new)
y_new = new_data[-1]

# Load the best model
with open(path + r"\model_lr_lag3.pkl", 'rb') as f:
    best_model_lr = pickle.load(f)
    
prediction = best_model_lr.predict(X_new)
print(f"Observation: {date_new} {float(y_new):.2f}")
print(f"Prediction: {date_new} {prediction[0]:.2f}")
# Out:
# Observation: 2023-05-09 307.00
# Prediction: 2023-05-09 308.63
