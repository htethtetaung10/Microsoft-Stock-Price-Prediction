# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
# Load data (data source: https://finance.yahoo.com/quote/MSFT/history/)
data = pd.read_csv(r"C:\Users\htet\Documents\backup\prediction_ms_stock_prices\MSFT.csv")
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063907
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...          ...         ...         ...         ...         ...         ...
# 9356  2023-04-27  295.970001  305.200012  295.250000  304.829987  304.829987
# 9357  2023-04-28  304.010010  308.929993  303.309998  307.260010  307.260010
# 9358  2023-05-01  306.970001  308.600006  305.149994  305.559998  305.559998
# 9359  2023-05-02  307.760010  309.179993  303.910004  305.410004  305.410004
# 9360  2023-05-03  306.619995  308.609985  304.089996  304.399994  304.399994
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9356    46462600
# 9357    36446700
# 9358    21294100
# 9359    26404400
# 9360    22303300
#
# [9361 rows x 7 columns]

# %%
def drop_columns(dataframe, cols):
    dataframe = dataframe.drop(cols, axis=1)
    return dataframe

data = drop_columns(data, ["Open", "High", "Low", "Adj Close", "Volume"])
data.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

data['Date'] = data['Date'].apply(str_to_datetime)
data['Date'].head()
# Out:
# 0   1986-03-13
# 1   1986-03-14
# 2   1986-03-17
# 3   1986-03-18
# 4   1986-03-19
# Name: Date, dtype: datetime64[ns]

# %%
data = data.set_index("Date")
data.head()
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090

# %%
data['Close'].describe()
# Out:
# count    9361.000000
# mean       47.864888
# std        69.759779
# min         0.090278
# 25%         5.304688
# 50%        27.080000
# 75%        43.360001
# max       343.109985
# Name: Close, dtype: float64

# %%
# Plot yearly closing values over time
plt.plot(data.index, data['Close'])
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Closing Values Over Time")
plt.grid()

# %%
# Yearly data distribution
data_year = data.Close.resample('Y').mean()
print(data_year.describe())

# Plot quaterly closing value over time
plt.plot(data_year.index, data_year)
plt.xlabel("Year")
plt.ylabel("Close")
plt.grid()
plt.title("Yearly Closing Value Over Time")
# Out:
# count     38.000000
# mean      51.474578
# std       75.109397
# min        0.117596
# 25%        5.778952
# 50%       26.852981
# 75%       43.438429
# max      275.940754
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Yearly Closing Value Over Time')

# %%
# Quarterly data distribution
data_quarter = data.Close.resample('Q').mean()
print(data_quarter.describe())

# Plot closing value over time
plt.plot(data_quarter.index, data_quarter)
plt.xlabel("Quarter")
plt.ylabel("Close")
plt.grid()
plt.title("Quarterly Closing Value Over Time")
# Out:
# count    150.000000
# mean      48.710331
# std       71.435336
# min        0.096282
# 25%        5.267330
# 50%       27.024108
# 75%       44.339050
# max      324.210157
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Quarterly Closing Value Over Time')

# %%
# Monthly data distribution
data_month = data.Close.resample('M').mean()
print(data_month.describe())

# Plot Monthly closing value over time
plt.plot(data_month.index, data_month)
plt.xlabel("Month")
plt.ylabel("Close")
plt.grid()
plt.title("Monthly Closing Value Over Time")
# Out:
# count    447.000000
# mean      48.411090
# std       70.663067
# min        0.096282
# 25%        5.456676
# 50%       27.075263
# 75%       43.514048
# max      335.870950
# Name: Close, dtype: float64
# Text(0.5, 1.0, 'Monthly Closing Value Over Time')

# %%
# Create windows based on lags
def create_window(df, lag):
    if lag < len(df):
        l = lag

        while True:
            df[f"Target_Close_{l}"] = df.Close.shift(l)

            l = l-1
            if l<1:
                break
        
        df["Target"] = df.Close.copy()
        return df
    
    else:
        raise ValueError(f"Lag value ({lag}) should be less than the size of data ({len(df)}).")

try:
    lag = 1
    target_data = data.copy()
    target_data = create_window(target_data, lag)
     
except ValueError as e:
    print(str(e))
    
target_data
# Out:
#                  Close  Target_Close_1      Target
# Date
# 1986-03-13    0.097222             NaN    0.097222
# 1986-03-14    0.100694        0.097222    0.100694
# 1986-03-17    0.102431        0.100694    0.102431
# 1986-03-18    0.099826        0.102431    0.099826
# 1986-03-19    0.098090        0.099826    0.098090
# ...                ...             ...         ...
# 2023-04-27  304.829987      295.369995  304.829987
# 2023-04-28  307.260010      304.829987  307.260010
# 2023-05-01  305.559998      307.260010  305.559998
# 2023-05-02  305.410004      305.559998  305.410004
# 2023-05-03  304.399994      305.410004  304.399994
#
# [9361 rows x 3 columns]

# %%
# Delete redundant columns
deleted_cols = ["Close"]
target_data = drop_columns(target_data, deleted_cols)
target_data
# Out:
#             Target_Close_1      Target
# Date
# 1986-03-13             NaN    0.097222
# 1986-03-14        0.097222    0.100694
# 1986-03-17        0.100694    0.102431
# 1986-03-18        0.102431    0.099826
# 1986-03-19        0.099826    0.098090
# ...                    ...         ...
# 2023-04-27      295.369995  304.829987
# 2023-04-28      304.829987  307.260010
# 2023-05-01      307.260010  305.559998
# 2023-05-02      305.559998  305.410004
# 2023-05-03      305.410004  304.399994
#
# [9361 rows x 2 columns]

# %%
# Choose data period
def selected_targets(dataframe, first_date, last_date):
    if first_date > dataframe.index[lag-1]:
        target_selected = dataframe.loc[first_date:last_date]
        return target_selected
    else:
        raise ValueError(f"First date should be greater than {first_date}.")     

try:  
    first_date = '1986-03-20'
    last_date = '2023-05-03'
    target_selected = selected_targets(target_data, str_to_datetime(first_date), str_to_datetime(last_date))
    print("Selected target shape: ", target_selected.shape)
    
except ValueError as e:
    print(str(e))
# Out:
# Selected target shape:  (9356, 2)

# %%
# Prepare data
def prepare_data(df):
    # convert df to numpy array
    dates = df.index.to_numpy()
    X = df.to_numpy()[:, :-1]
    y = df.to_numpy()[:, -1]
    return dates, X, y
    
dates, X, y = prepare_data(target_selected)
dates.shape, X.shape, y.shape
# Out:
# ((9356,), (9356, 1), (9356,))

# %%
# Split train and test data
train_size = int(len(dates)*0.8)
dates_train = dates[:train_size]
X_train = X[:train_size]
y_train = y[:train_size]
dates_test = dates[train_size:]
X_test = X[train_size:]
y_test = y[train_size:]

X_train.shape, X_test.shape
# Out:
# ((7484, 1), (1872, 1))

# %%
# Split train and validation data
train_nn_size = int(len(dates_train)*0.8)
dates_train_nn = dates_train[:train_nn_size]
X_train_nn = X_train[:train_nn_size]
y_train_nn = y_train[:train_nn_size]
dates_val_nn = dates_train[train_nn_size:]
X_val_nn = X_train[train_nn_size:]
y_val_nn = y_train[train_nn_size:]

X_train_nn.shape, X_val_nn.shape
# Out:
# ((5987, 1), (1497, 1))

# %%
# Standardize X data
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_train_nn = scaler.transform(X_train_nn)
X_val_nn = scaler.transform(X_val_nn)

# %%
# Plot train and test data
plt.plot(dates_train, y_train)
plt.plot(dates_test, y_test)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Closing Values Over Time of Train and Test Data")
plt.grid()
plt.legend(["Train", "Test"])

# %%
# Train and test target data distribution
pd.DataFrame(y_train).describe(), pd.DataFrame(y_test).describe()
# Out:
# (                 0
#  count  7484.000000
#  mean     19.820053
#  std      14.861314
#  min       0.090278
#  25%       2.667643
#  50%      25.085000
#  75%      29.350000
#  max      59.562500,
#                   0
#  count  1872.000000
#  mean    160.111880
#  std      87.769884
#  min      48.430000
#  25%      75.407501
#  50%     137.099998
#  75%     242.497501
#  max     343.109985)

# %%
# Create linear regression model
model_lr = LinearRegression(fit_intercept='True')
model_sv = SVR(kernel='linear', C=0.1, epsilon=0.1)
model_rf = RandomForestRegressor(n_estimators=50, max_depth=None)
model_gb = GradientBoostingRegressor(n_estimators=50, learning_rate=0.1, max_depth=3)
model_kn = KNeighborsRegressor(n_neighbors=3, weights='uniform')

# Set the time series cross-validation scheme
tscv = TimeSeriesSplit(n_splits=6)
mae_scores_lr = 0.0
mae_scores_sv = 0.0
mae_scores_rf = 0.0
mae_scores_gb = 0.0
mae_scores_kn = 0.0

for train_index, val_index in tscv.split(X_train):
    X_train_cv, X_val = X_train[train_index], X_train[val_index]
    y_train_cv, y_val = y_train[train_index], y_train[val_index]
    
    # Train models
    model_lr.fit(X_train, y_train)
    model_sv.fit(X_train, y_train)
    model_rf.fit(X_train, y_train)
    model_gb.fit(X_train, y_train)
    model_kn.fit(X_train, y_train)

    # Evaluate performance on the validation set
    y_pred_val_lr = model_lr.predict(X_val)
    y_pred_val_sv = model_sv.predict(X_val)
    y_pred_val_rf = model_rf.predict(X_val)
    y_pred_val_gb = model_gb.predict(X_val)
    y_pred_val_kn = model_kn.predict(X_val)
    mae_scores_lr += mean_absolute_error(y_val, y_pred_val_lr)
    mae_scores_sv += mean_absolute_error(y_val, y_pred_val_sv)
    mae_scores_rf += mean_absolute_error(y_val, y_pred_val_rf)
    mae_scores_gb += mean_absolute_error(y_val, y_pred_val_gb)
    mae_scores_kn += mean_absolute_error(y_val, y_pred_val_kn)

print("***Validation Scores***")
print('Validation MAE (Linear Regression): ', mae_scores_lr)
print('Validation MAE (Support Vector Regressor): ', mae_scores_sv)
print('Validation MAE (Random Forest Regressor): ', mae_scores_rf)
print('Validation MAE (Gradient Boosting Regressor): ', mae_scores_gb)
print('Validation MAE (KNeighbors regressor): ', mae_scores_kn)
# Out:
# ***Validation Scores***
# Validation MAE (Linear Regression):  1.94487402806482
# Validation MAE (Support Vector Regressor):  1.957336996880898
# Validation MAE (Random Forest Regressor):  1.3159094924584038
# Validation MAE (Gradient Boosting Regressor):  2.0019215290817542
# Validation MAE (KNeighbors regressor):  1.7224534312441535

# %%
# Define the hyperparameters for neural networks
best_hps = {'num_layers': 23, 'units_0': 416, 'units_1': 160, 'learning_rate': 1e-05, 'units_2': 192, 'units_3': 608, 
            'units_4': 608, 'units_5': 416, 'units_6': 960, 'units_7': 608, 'units_8': 128, 'units_9': 896, 
            'units_10': 160, 'units_11': 864, 'units_12': 544, 'units_13': 704, 'units_14': 224, 'units_15': 1024, 
            'units_16': 224, 'units_17': 800, 'units_18': 32, 'units_19': 32, 'units_20': 32, 'units_21': 32, 
            'units_22': 32}

# Build the model
model_nn = Sequential()
for i in range(best_hps['num_layers']):
    units = best_hps[f'units_{i}']
    if i == 0:
        model_nn.add(Dense(units=units, activation='relu', input_shape=(1,)))
    else:
        model_nn.add(Dense(units=units, activation='relu'))
model_nn.add(Dense(units=1, activation='linear'))

# Compile the model
optimizer = Adam(learning_rate=best_hps['learning_rate'])
model_nn.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mean_absolute_error'])

# Train the model using the full training set
history = model_nn.fit(X_train_nn, y_train_nn, epochs=100, validation_data=(X_val_nn, y_val_nn))
# Out:
# Epoch 1/100
# 188/188 [==============================] - 20s 67ms/step - loss: 16.1835 - mean_absolute_error: 16.1835 - val_loss: 30.0553 - val_mean_absolute_error: 30.0553
# Epoch 2/100
# 188/188 [==============================] - 12s 61ms/step - loss: 7.0005 - mean_absolute_error: 7.0005 - val_loss: 5.4725 - val_mean_absolute_error: 5.4725
# Epoch 3/100
# 188/188 [==============================] - 12s 63ms/step - loss: 2.3437 - mean_absolute_error: 2.3437 - val_loss: 1.8460 - val_mean_absolute_error: 1.8460
# Epoch 4/100
# 188/188 [==============================] - 12s 64ms/step - loss: 0.4580 - mean_absolute_error: 0.4580 - val_loss: 0.4116 - val_mean_absolute_error: 0.4116
# Epoch 5/100
# 188/188 [==============================] - 12s 63ms/step - loss: 0.3232 - mean_absolute_error: 0.3232 - val_loss: 0.4590 - val_mean_absolute_error: 0.4590
# Epoch 6/100
# 188/188 [==============================] - 12s 64ms/step - loss: 0.3001 - mean_absolute_error: 0.3001 - val_loss: 0.3601 - val_mean_absolute_error: 0.3601
# Epoch 7/100
# 188/188 [==============================] - 11s 61ms/step - loss: 0.2942 - mean_absolute_error: 0.2942 - val_loss: 0.4981 - val_mean_absolute_error: 0.4981
# Epoch 8/100
# 188/188 [==============================] - 11s 60ms/step - loss: 0.2925 - mean_absolute_error: 0.2925 - val_loss: 0.3675 - val_mean_absolute_error: 0.3675
# Epoch 9/100
# 188/188 [==============================] - 11s 60ms/step - loss: 0.2883 - mean_absolute_error: 0.2883 - val_loss: 0.4250 - val_mean_absolute_error: 0.4250
# Epoch 10/100
# 188/188 [==============================] - 12s 62ms/step - loss: 0.2876 - mean_absolute_error: 0.2876 - val_loss: 0.3618 - val_mean_absolute_error: 0.3618
# Epoch 11/100
# 188/188 [==============================] - 12s 62ms/step - loss: 0.2952 - mean_absolute_error: 0.2952 - val_loss: 0.4651 - val_mean_absolute_error: 0.4651
# Epoch 12/100
# 188/188 [==============================] - 12s 62ms/step - loss: 0.2833 - mean_absolute_error: 0.2833 - val_loss: 0.3637 - val_mean_absolute_error: 0.3637
# Epoch 13/100
# 188/188 [==============================] - 11s 61ms/step - loss: 0.2864 - mean_absolute_error: 0.2864 - val_loss: 0.4786 - val_mean_absolute_error: 0.4786
# Epoch 14/100
# 188/188 [==============================] - 12s 61ms/step - loss: 0.2881 - mean_absolute_error: 0.2881 - val_loss: 0.5413 - val_mean_absolute_error: 0.5413
# Epoch 15/100
# 188/188 [==============================] - 12s 61ms/step - loss: 0.2821 - mean_absolute_error: 0.2821 - val_loss: 0.3513 - val_mean_absolute_error: 0.3513
# Epoch 16/100
# 188/188 [==============================] - 12s 62ms/step - loss: 0.2903 - mean_absolute_error: 0.2903 - val_loss: 0.3590 - val_mean_absolute_error: 0.3590
# Epoch 17/100
# 188/188 [==============================] - 12s 62ms/step - loss: 0.2876 - mean_absolute_error: 0.2876 - val_loss: 0.3520 - val_mean_absolute_error: 0.3520
# Epoch 18/100
# 188/188 [==============================] - 12s 62ms/step - loss: 0.2900 - mean_absolute_error: 0.2900 - val_loss: 0.3571 - val_mean_absolute_error: 0.3571
# Epoch 19/100
# 188/188 [==============================] - 12s 65ms/step - loss: 0.2885 - mean_absolute_error: 0.2885 - val_loss: 0.3788 - val_mean_absolute_error: 0.3788
# Epoch 20/100
# 188/188 [==============================] - 12s 62ms/step - loss: 0.2980 - mean_absolute_error: 0.2980 - val_loss: 0.3762 - val_mean_absolute_error: 0.3762
# Epoch 21/100
# 188/188 [==============================] - 10s 55ms/step - loss: 0.2809 - mean_absolute_error: 0.2809 - val_loss: 0.7669 - val_mean_absolute_error: 0.7669
# Epoch 22/100
# 188/188 [==============================] - 11s 58ms/step - loss: 0.2904 - mean_absolute_error: 0.2904 - val_loss: 0.6546 - val_mean_absolute_error: 0.6546
# Epoch 23/100
# 188/188 [==============================] - 10s 55ms/step - loss: 0.2814 - mean_absolute_error: 0.2814 - val_loss: 0.5277 - val_mean_absolute_error: 0.5277
# Epoch 24/100
# 188/188 [==============================] - 11s 58ms/step - loss: 0.2940 - mean_absolute_error: 0.2940 - val_loss: 0.3509 - val_mean_absolute_error: 0.3509
# Epoch 25/100
# 188/188 [==============================] - 10s 55ms/step - loss: 0.2822 - mean_absolute_error: 0.2822 - val_loss: 0.3574 - val_mean_absolute_error: 0.3574
# Epoch 26/100
# 188/188 [==============================] - 10s 55ms/step - loss: 0.2914 - mean_absolute_error: 0.2914 - val_loss: 0.3747 - val_mean_absolute_error: 0.3747
# Epoch 27/100
# 188/188 [==============================] - 10s 54ms/step - loss: 0.2832 - mean_absolute_error: 0.2832 - val_loss: 0.3547 - val_mean_absolute_error: 0.3547
# Epoch 28/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.2865 - mean_absolute_error: 0.2865 - val_loss: 0.3670 - val_mean_absolute_error: 0.3670
# Epoch 29/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.2853 - mean_absolute_error: 0.2853 - val_loss: 0.3773 - val_mean_absolute_error: 0.3773
# Epoch 30/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.2803 - mean_absolute_error: 0.2803 - val_loss: 0.3496 - val_mean_absolute_error: 0.3496
# Epoch 31/100
# 188/188 [==============================] - 10s 54ms/step - loss: 0.3023 - mean_absolute_error: 0.3023 - val_loss: 0.4621 - val_mean_absolute_error: 0.4621
# Epoch 32/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.2890 - mean_absolute_error: 0.2890 - val_loss: 0.3514 - val_mean_absolute_error: 0.3514
# Epoch 33/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2761 - mean_absolute_error: 0.2761 - val_loss: 0.4105 - val_mean_absolute_error: 0.4105
# Epoch 34/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2926 - mean_absolute_error: 0.2926 - val_loss: 0.3521 - val_mean_absolute_error: 0.3521
# Epoch 35/100
# 188/188 [==============================] - 10s 56ms/step - loss: 0.3054 - mean_absolute_error: 0.3054 - val_loss: 0.3700 - val_mean_absolute_error: 0.3700
# Epoch 36/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.2851 - mean_absolute_error: 0.2851 - val_loss: 0.4873 - val_mean_absolute_error: 0.4873
# Epoch 37/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.2744 - mean_absolute_error: 0.2744 - val_loss: 0.3619 - val_mean_absolute_error: 0.3619
# Epoch 38/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.2872 - mean_absolute_error: 0.2872 - val_loss: 0.4312 - val_mean_absolute_error: 0.4312
# Epoch 39/100
# 188/188 [==============================] - 10s 56ms/step - loss: 0.2763 - mean_absolute_error: 0.2763 - val_loss: 0.6222 - val_mean_absolute_error: 0.6222
# Epoch 40/100
# 188/188 [==============================] - 11s 60ms/step - loss: 0.2817 - mean_absolute_error: 0.2817 - val_loss: 0.3497 - val_mean_absolute_error: 0.3497
# Epoch 41/100
# 188/188 [==============================] - 10s 55ms/step - loss: 0.2823 - mean_absolute_error: 0.2823 - val_loss: 0.3703 - val_mean_absolute_error: 0.3703
# Epoch 42/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.2882 - mean_absolute_error: 0.2882 - val_loss: 0.3853 - val_mean_absolute_error: 0.3853
# Epoch 43/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2881 - mean_absolute_error: 0.2881 - val_loss: 0.4089 - val_mean_absolute_error: 0.4089
# Epoch 44/100
# 188/188 [==============================] - 10s 50ms/step - loss: 0.2840 - mean_absolute_error: 0.2840 - val_loss: 0.4750 - val_mean_absolute_error: 0.4750
# Epoch 45/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2821 - mean_absolute_error: 0.2821 - val_loss: 0.4423 - val_mean_absolute_error: 0.4423
# Epoch 46/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2915 - mean_absolute_error: 0.2915 - val_loss: 0.5937 - val_mean_absolute_error: 0.5937
# Epoch 47/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2889 - mean_absolute_error: 0.2889 - val_loss: 0.3908 - val_mean_absolute_error: 0.3908
# Epoch 48/100
# 188/188 [==============================] - 10s 53ms/step - loss: 0.2760 - mean_absolute_error: 0.2760 - val_loss: 0.3651 - val_mean_absolute_error: 0.3651
# Epoch 49/100
# 188/188 [==============================] - 10s 53ms/step - loss: 0.2793 - mean_absolute_error: 0.2793 - val_loss: 0.4801 - val_mean_absolute_error: 0.4801
# Epoch 50/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.2927 - mean_absolute_error: 0.2927 - val_loss: 0.3816 - val_mean_absolute_error: 0.3816
# Epoch 51/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2819 - mean_absolute_error: 0.2819 - val_loss: 0.5374 - val_mean_absolute_error: 0.5374
# Epoch 52/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2878 - mean_absolute_error: 0.2878 - val_loss: 0.4014 - val_mean_absolute_error: 0.4014
# Epoch 53/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2890 - mean_absolute_error: 0.2890 - val_loss: 0.3606 - val_mean_absolute_error: 0.3606
# Epoch 54/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2928 - mean_absolute_error: 0.2928 - val_loss: 0.3504 - val_mean_absolute_error: 0.3504
# Epoch 55/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2838 - mean_absolute_error: 0.2838 - val_loss: 0.4819 - val_mean_absolute_error: 0.4819
# Epoch 56/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2892 - mean_absolute_error: 0.2892 - val_loss: 0.4141 - val_mean_absolute_error: 0.4141
# Epoch 57/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2910 - mean_absolute_error: 0.2910 - val_loss: 0.3493 - val_mean_absolute_error: 0.3493
# Epoch 58/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2819 - mean_absolute_error: 0.2819 - val_loss: 0.3533 - val_mean_absolute_error: 0.3533
# Epoch 59/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2768 - mean_absolute_error: 0.2768 - val_loss: 0.4051 - val_mean_absolute_error: 0.4051
# Epoch 60/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2942 - mean_absolute_error: 0.2942 - val_loss: 0.3937 - val_mean_absolute_error: 0.3937
# Epoch 61/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2900 - mean_absolute_error: 0.2900 - val_loss: 0.3893 - val_mean_absolute_error: 0.3893
# Epoch 62/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2816 - mean_absolute_error: 0.2816 - val_loss: 0.3700 - val_mean_absolute_error: 0.3700
# Epoch 63/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2824 - mean_absolute_error: 0.2824 - val_loss: 0.3581 - val_mean_absolute_error: 0.3581
# Epoch 64/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2779 - mean_absolute_error: 0.2779 - val_loss: 0.4089 - val_mean_absolute_error: 0.4089
# Epoch 65/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2851 - mean_absolute_error: 0.2851 - val_loss: 0.4988 - val_mean_absolute_error: 0.4988
# Epoch 66/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2887 - mean_absolute_error: 0.2887 - val_loss: 0.9447 - val_mean_absolute_error: 0.9447
# Epoch 67/100
# 188/188 [==============================] - 10s 56ms/step - loss: 0.2928 - mean_absolute_error: 0.2928 - val_loss: 0.3567 - val_mean_absolute_error: 0.3567
# Epoch 68/100
# 188/188 [==============================] - 11s 57ms/step - loss: 0.2867 - mean_absolute_error: 0.2867 - val_loss: 0.3704 - val_mean_absolute_error: 0.3704
# Epoch 69/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2871 - mean_absolute_error: 0.2871 - val_loss: 0.5339 - val_mean_absolute_error: 0.5339
# Epoch 70/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2879 - mean_absolute_error: 0.2879 - val_loss: 0.4884 - val_mean_absolute_error: 0.4884
# Epoch 71/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2939 - mean_absolute_error: 0.2939 - val_loss: 0.4536 - val_mean_absolute_error: 0.4536
# Epoch 72/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2866 - mean_absolute_error: 0.2866 - val_loss: 0.3923 - val_mean_absolute_error: 0.3923
# Epoch 73/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2827 - mean_absolute_error: 0.2827 - val_loss: 0.5258 - val_mean_absolute_error: 0.5258
# Epoch 74/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2872 - mean_absolute_error: 0.2872 - val_loss: 0.3622 - val_mean_absolute_error: 0.3622
# Epoch 75/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2916 - mean_absolute_error: 0.2916 - val_loss: 0.3571 - val_mean_absolute_error: 0.3571
# Epoch 76/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2846 - mean_absolute_error: 0.2846 - val_loss: 0.3606 - val_mean_absolute_error: 0.3606
# Epoch 77/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2875 - mean_absolute_error: 0.2875 - val_loss: 0.5037 - val_mean_absolute_error: 0.5037
# Epoch 78/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2827 - mean_absolute_error: 0.2827 - val_loss: 0.3540 - val_mean_absolute_error: 0.3540
# Epoch 79/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2901 - mean_absolute_error: 0.2901 - val_loss: 0.4363 - val_mean_absolute_error: 0.4363
# Epoch 80/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2897 - mean_absolute_error: 0.2897 - val_loss: 0.3915 - val_mean_absolute_error: 0.3915
# Epoch 81/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2831 - mean_absolute_error: 0.2831 - val_loss: 0.3676 - val_mean_absolute_error: 0.3676
# Epoch 82/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2867 - mean_absolute_error: 0.2867 - val_loss: 0.4075 - val_mean_absolute_error: 0.4075
# Epoch 83/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2826 - mean_absolute_error: 0.2826 - val_loss: 0.5233 - val_mean_absolute_error: 0.5233
# Epoch 84/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2875 - mean_absolute_error: 0.2875 - val_loss: 0.4152 - val_mean_absolute_error: 0.4152
# Epoch 85/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2792 - mean_absolute_error: 0.2792 - val_loss: 0.3512 - val_mean_absolute_error: 0.3512
# Epoch 86/100
# 188/188 [==============================] - 10s 53ms/step - loss: 0.2826 - mean_absolute_error: 0.2826 - val_loss: 0.5475 - val_mean_absolute_error: 0.5475
# Epoch 87/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2873 - mean_absolute_error: 0.2873 - val_loss: 0.3770 - val_mean_absolute_error: 0.3770
# Epoch 88/100
# 188/188 [==============================] - 10s 53ms/step - loss: 0.2849 - mean_absolute_error: 0.2849 - val_loss: 0.3515 - val_mean_absolute_error: 0.3515
# Epoch 89/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2846 - mean_absolute_error: 0.2846 - val_loss: 0.3717 - val_mean_absolute_error: 0.3717
# Epoch 90/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2809 - mean_absolute_error: 0.2809 - val_loss: 0.4242 - val_mean_absolute_error: 0.4242
# Epoch 91/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2805 - mean_absolute_error: 0.2805 - val_loss: 0.3526 - val_mean_absolute_error: 0.3526
# Epoch 92/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2875 - mean_absolute_error: 0.2875 - val_loss: 0.3520 - val_mean_absolute_error: 0.3520
# Epoch 93/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2804 - mean_absolute_error: 0.2804 - val_loss: 0.4465 - val_mean_absolute_error: 0.4465
# Epoch 94/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2923 - mean_absolute_error: 0.2923 - val_loss: 0.3571 - val_mean_absolute_error: 0.3571
# Epoch 95/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2800 - mean_absolute_error: 0.2800 - val_loss: 0.4236 - val_mean_absolute_error: 0.4236
# Epoch 96/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2849 - mean_absolute_error: 0.2849 - val_loss: 0.3538 - val_mean_absolute_error: 0.3538
# Epoch 97/100
# 188/188 [==============================] - 10s 53ms/step - loss: 0.2868 - mean_absolute_error: 0.2868 - val_loss: 0.3748 - val_mean_absolute_error: 0.3748
# Epoch 98/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2883 - mean_absolute_error: 0.2883 - val_loss: 0.5531 - val_mean_absolute_error: 0.5531
# Epoch 99/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2889 - mean_absolute_error: 0.2889 - val_loss: 0.3726 - val_mean_absolute_error: 0.3726
# Epoch 100/100
# 188/188 [==============================] - 9s 50ms/step - loss: 0.2843 - mean_absolute_error: 0.2843 - val_loss: 0.3858 - val_mean_absolute_error: 0.3858

# %%
# Save the models
path = r'C:\Users\htet\Documents\backup\prediction_ms_stock_prices'

with open(path + r"\model_lr_lag1.pkl", 'wb') as f:
    pickle.dump(model_lr, f)
    
with open(path + r"\model_sv_lag1.pkl", 'wb') as f:
    pickle.dump(model_sv, f)

with open(path + r"\model_rf_lag1.pkl", 'wb') as f:
    pickle.dump(model_rf, f)
    
with open(path + r"\model_gb_lag1.pkl", 'wb') as f:
    pickle.dump(model_gb, f)
    
with open(path + r"\model_kn_lag1.pkl", 'wb') as f:
    pickle.dump(model_kn, f)
    
with open(path + r"\model_nn_lag1.pkl", 'wb') as f:
    pickle.dump(model_nn, f)

# %%
# Make predictions
y_pred_test_lr = model_lr.predict(X_test)
y_pred_test_sv = model_sv.predict(X_test)
y_pred_test_rf = model_rf.predict(X_test)
y_pred_test_gb = model_gb.predict(X_test)
y_pred_test_kn = model_kn.predict(X_test)
y_pred_test_nn = model_nn.predict(X_test)

# Evaluate model performance
mae_lr = mean_absolute_error(y_test, y_pred_test_lr)
mae_sv = mean_absolute_error(y_test, y_pred_test_sv)
mae_rf = mean_absolute_error(y_test, y_pred_test_rf)
mae_gb = mean_absolute_error(y_test, y_pred_test_gb)
mae_kn = mean_absolute_error(y_test, y_pred_test_kn)
mae_nn = mean_absolute_error(y_test, y_pred_test_nn)

mse_lr = mean_squared_error(y_test, y_pred_test_lr)
mse_sv = mean_squared_error(y_test, y_pred_test_sv)
mse_rf = mean_squared_error(y_test, y_pred_test_rf)
mse_gb = mean_squared_error(y_test, y_pred_test_gb)
mse_kn = mean_squared_error(y_test, y_pred_test_kn)
mse_nn = mean_squared_error(y_test, y_pred_test_nn)

rmse_lr = mse_lr ** 0.5
rmse_sv = mse_sv ** 0.5
rmse_rf = mse_rf ** 0.5
rmse_gb = mse_gb ** 0.5
rmse_kn = mse_kn ** 0.5
rmse_nn = mse_nn ** 0.5

print("\n*****Testing score******")
print("\n***Linear Regression***")
print('MAE: %.2f' % mae_lr)
print('MSE: %.2f' % mse_lr)
print('RMSE: %.2f' % rmse_lr)
print("\n***Support Vector Regressor***")
print('MAE: %.2f' % mae_sv)
print('MSE: %.2f' % mse_sv)
print('RMSE: %.2f' % rmse_sv)
print("\n***Random Forest Regressor***")
print('MAE: %.2f' % mae_rf)
print('MSE: %.2f' % mse_rf)
print('RMSE: %.2f' % rmse_rf)
print("\n***Gradient Boosting Regressor***")
print('MAE: %.2f' % mae_gb)
print('MSE: %.2f' % mse_gb)
print('RMSE: %.2f' % rmse_gb)
print("\n***KNeighbors regressor***")
print('MAE: %.2f' % mae_kn)
print('MSE: %.2f' % mse_kn)
print('RMSE: %.2f' % rmse_kn)
print("\n***Neural Networks***")
print('MAE: %.2f' % mae_nn)
print('MSE: %.2f' % mse_nn)
print('RMSE: %.2f' % rmse_nn)
# Out:
# 59/59 [==============================] - 1s 10ms/step
#
# *****Testing score******
#
# ***Linear Regression***
# MAE: 2.10
# MSE: 11.67
# RMSE: 3.42
#
# ***Support Vector Regressor***
# MAE: 2.13
# MSE: 11.82
# RMSE: 3.44
#
# ***Random Forest Regressor***
# MAE: 102.08
# MSE: 17969.81
# RMSE: 134.05
#
# ***Gradient Boosting Regressor***
# MAE: 102.80
# MSE: 18143.42
# RMSE: 134.70
#
# ***KNeighbors regressor***
# MAE: 102.16
# MSE: 17991.52
# RMSE: 134.13
#
# ***Neural Networks***
# MAE: 5.33
# MSE: 59.98
# RMSE: 7.74

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_lr)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Linear Regression)")
plt.grid()
plt.legend(["Test observation", 
            "Linear Regression prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_sv)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Support Vector Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Support Vector Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_rf)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Random Forest Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Random Forest Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_gb)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Gradient Boosting Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "Gradient Boosting Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_nn)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (KNeighbors Regressor)")
plt.grid()
plt.legend(["Test observation", 
            "KNeighbors Regressor prediction"])

# %%
# Plot the model performance
plt.plot(dates_test, y_test)
plt.plot(dates_test, y_pred_test_nn)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Prediction and Observation of Closing Value Over Time (Neural Networks)")
plt.grid()
plt.legend(["Test observation", 
            "Neural Networks prediction"])

# %%
# Predict new data
new_data = np.array(['2023-05-09', 308.65, 307.00])
date_new = new_data[0]
X_new = new_data[1:-1]
X_new = X_new.reshape((-1, len(X_new)))
X_new = scaler.transform(X_new)
y_new = new_data[-1]

# Load the best model
with open(path + r"\model_lr_lag1.pkl", 'rb') as f:
    best_model_lr = pickle.load(f)
    
prediction = best_model_lr.predict(X_new)
print(f"Observation: {date_new} {float(y_new):.2f}")
print(f"Prediction: {date_new} {prediction[0]:.2f}")
# Out:
# Observation: 2023-05-09 307.00
# Prediction: 2023-05-09 308.56
